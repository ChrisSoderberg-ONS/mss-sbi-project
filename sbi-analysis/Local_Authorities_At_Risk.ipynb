# %%
#First recreate the data from the preliminary analysis
import geopandas as gpd
import pandas as pd


# Load and join GMCA housing, industrial and office supply data
housing_supply_gdf = gpd.read_file("data/gmca_data/2024 GM Housing Land Supply GIS.shp")
industrial_supply_gdf = gpd.read_file("data/gmca_data/2024 GM Industrial-warehousing Land Supply GIS.shp")
offices_supply_gdf = gpd.read_file("data/gmca_data/2024 GM Offices Land Supply GIS.shp")
total_supply_gdf = pd.concat(
    [housing_supply_gdf, industrial_supply_gdf, offices_supply_gdf]
)

# Load and tidy GMEU Sites of Biological Importance data
sbi_gdf = gpd.read_file("data/gmeu_data/gm_sbi.shp")
sbi_gdf["Category"] = "Site of Biological Importance"
sbi_gdf = sbi_gdf.rename(columns = {"district": "LAName", "site_nam": "SiteRef"})

# Join GMCA and GMEU data
full_data_gdf = pd.concat(
    [total_supply_gdf, sbi_gdf[["SiteRef", "LAName", "Category", "geometry"]]]
)

#Use geopandas to get centroids of all the sites
full_data_gdf["centroid"] = full_data_gdf.centroid
full_data_gdf["ref"] = range(len(full_data_gdf))

#Split into sites of biological importance and non-biological importance
sbi = full_data_gdf[full_data_gdf["Category"] == "Site of Biological Importance"]
non_sbi = full_data_gdf[full_data_gdf["Category"] != "Site of Biological Importance"]

#Find the number of new developments less than 1km away for each SBI
sbinames = list(sbi["SiteRef"]) 
indexes = list(sbi["ref"])


#list of all the sbis
distances = list()
less_than_1km = list() #creating empty lists to add to data frame

for x in sbi["centroid"]: #loop through each sbi
    y = non_sbi["centroid"].distance(x) #find all the distances of developments to centroid
    for distance in y: #filter for less than 1km away
            if distance <1000:
                distances.append(distance)
    r = len(distances)    #find no. developments less than 1km away to each sbi
    less_than_1km.append(r)
    distances = list()

Dev_1km = pd.DataFrame({'SiteRef':sbinames, 'No. Sites in 1km': less_than_1km, 'ref': indexes}) #create dataframe of sbi and no. developments     


Dev_1km
# Out:
#                                   SiteRef  No. Sites in 1km   ref
# 0                                Big Wood                 0  4357
# 1                   Winstanley Hall Woods                 1  4358
# 2             Ackhurst Lane Sand Workings                 3  4359
# 3                             Abbey Lakes                 6  4360
# 4                           Wetland by M6                 1  4361
# ..                                    ...               ...   ...
# 531  Mill Race & Pasture at Haughton Dale                 8  4888
# 532                         Three Sisters                 2  4889
# 533                         Nan Nook Wood                 7  4890
# 534                              Big Wood                10  4891
# 535                     Bank Wood & Marsh                11  4892
#
# [536 rows x 3 columns]

# %%
#Obtaining the joined list
boundaries = gpd.read_file("data/boundaries/LAD_DEC_24_UK_BUC.shp")

pd.merge(full_data_gdf, boundaries, left_on = "LAName", right_on = "LAD24NM", how = "left")

joined_one = pd.merge(full_data_gdf, boundaries, left_on = "LAName", right_on = "LAD24NM", how = "left")

# %%
joined_one = joined_one.drop(columns=["LAD24NM","LAD24NMW","BNG_E","BNG_N","LONG","LAT","GlobalID","LAD24CD"])

# %%
joined_one.rename(columns={'geometry_x': 'SBI_Location', 'geometry_y': 'Local Authority'}, inplace=True)

# %%
joined_one
# Out:
#                            Category      LAName  \
# 0                           Housing        Bury
# 1                           Housing        Bury
# 2                           Housing        Bury
# 3                           Housing        Bury
# 4                           Housing        Bury
# ...                             ...         ...
# 4888  Site of Biological Importance    Tameside
# 4889  Site of Biological Importance       Wigan
# 4890  Site of Biological Importance  Manchester
# 4891  Site of Biological Importance  Manchester
# 4892  Site of Biological Importance      Bolton
#
#                                    SiteRef  \
# 0                               HL/0414/00
# 1                               HL/1172/00
# 2                               HL/1981/00
# 3                               HL/2004/00
# 4                               HL/2127/00
# ...                                    ...
# 4888  Mill Race & Pasture at Haughton Dale
# 4889                         Three Sisters
# 4890                         Nan Nook Wood
# 4891                              Big Wood
# 4892                     Bank Wood & Marsh
#
#                                            SBI_Location  \
# 0     POLYGON ((379112.8 410310.51, 379117.56 410306...
# 1     POLYGON ((377973.95 414475.81, 377979.24 41446...
# 2     POLYGON ((380839 413359.78, 380838.6 413361.95...
# 3     POLYGON ((378834 407567.1, 378840 407566.81, 3...
# 4     POLYGON ((379113.7 410329.59, 379114.66 410328...
# ...                                                 ...
# 4888  MULTIPOLYGON (((393687.128 393384.895, 393682....
# 4889  POLYGON ((357928.939 401185.293, 357957.618 40...
# 4890  POLYGON ((381158.403 390125.048, 381156.853 39...
# 4891  MULTIPOLYGON (((383512.797 386267.952, 383512....
# 4892  POLYGON ((369344.075 408685.587, 369329.313 40...
#
#                            centroid   ref  \
# 0     POINT (379114.012 410213.116)     0
# 1     POINT (377947.835 414384.462)     1
# 2     POINT (380885.718 413390.494)     2
# 3       POINT (378852.408 407559.6)     3
# 4       POINT (379117.39 410313.26)     4
# ...                             ...   ...
# 4888  POINT (393841.341 393512.227)  4888
# 4889  POINT (358367.769 401012.636)  4889
# 4890  POINT (380888.856 390037.976)  4890
# 4891  POINT (383309.435 386406.658)  4891
# 4892  POINT (368971.201 408737.581)  4892
#
#                                         Local Authority
# 0     POLYGON ((382118.504 413135.864, 383878.498 41...
# 1     POLYGON ((382118.504 413135.864, 383878.498 41...
# 2     POLYGON ((382118.504 413135.864, 383878.498 41...
# 3     POLYGON ((382118.504 413135.864, 383878.498 41...
# 4     POLYGON ((382118.504 413135.864, 383878.498 41...
# ...                                                 ...
# 4888  POLYGON ((402525.503 401459.003, 400905.596 39...
# 4889  POLYGON ((358668.063 410971.684, 361851.801 40...
# 4890  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4891  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4892  POLYGON ((375025.76 414990.104, 374998.996 413...
#
# [4893 rows x 7 columns]

# %%
pd.merge(joined_one, Dev_1km, left_on = "ref", right_on = "ref")
joined_two = pd.merge(joined_one, Dev_1km, left_on = "ref", right_on = "ref")

# %%
joined_two
# Out:
#                           Category      LAName  \
# 0    Site of Biological Importance       Wigan
# 1    Site of Biological Importance       Wigan
# 2    Site of Biological Importance       Wigan
# 3    Site of Biological Importance       Wigan
# 4    Site of Biological Importance       Wigan
# ..                             ...         ...
# 531  Site of Biological Importance    Tameside
# 532  Site of Biological Importance       Wigan
# 533  Site of Biological Importance  Manchester
# 534  Site of Biological Importance  Manchester
# 535  Site of Biological Importance      Bolton
#
#                                 SiteRef_x  \
# 0                                Big Wood
# 1                   Winstanley Hall Woods
# 2             Ackhurst Lane Sand Workings
# 3                             Abbey Lakes
# 4                           Wetland by M6
# ..                                    ...
# 531  Mill Race & Pasture at Haughton Dale
# 532                         Three Sisters
# 533                         Nan Nook Wood
# 534                              Big Wood
# 535                     Bank Wood & Marsh
#
#                                           SBI_Location  \
# 0    POLYGON ((353649.752 410536.46, 353660.55 4105...
# 1    MULTIPOLYGON (((354300.461 403639.988, 354318....
# 2    POLYGON ((354320.268 407088.639, 354329.097 40...
# 3    POLYGON ((352622.159 404628.83, 352625.623 404...
# 4    MULTIPOLYGON (((354408.45 411806.416, 354430.9...
# ..                                                 ...
# 531  MULTIPOLYGON (((393687.128 393384.895, 393682....
# 532  POLYGON ((357928.939 401185.293, 357957.618 40...
# 533  POLYGON ((381158.403 390125.048, 381156.853 39...
# 534  MULTIPOLYGON (((383512.797 386267.952, 383512....
# 535  POLYGON ((369344.075 408685.587, 369329.313 40...
#
#                           centroid   ref  \
# 0    POINT (353331.975 410159.462)  4357
# 1    POINT (354500.103 403252.365)  4358
# 2     POINT (354217.366 407048.76)  4359
# 3     POINT (352671.79 404738.385)  4360
# 4     POINT (354504.673 411797.58)  4361
# ..                             ...   ...
# 531  POINT (393841.341 393512.227)  4888
# 532  POINT (358367.769 401012.636)  4889
# 533  POINT (380888.856 390037.976)  4890
# 534  POINT (383309.435 386406.658)  4891
# 535  POINT (368971.201 408737.581)  4892
#
#                                        Local Authority  \
# 0    POLYGON ((358668.063 410971.684, 361851.801 40...
# 1    POLYGON ((358668.063 410971.684, 361851.801 40...
# 2    POLYGON ((358668.063 410971.684, 361851.801 40...
# 3    POLYGON ((358668.063 410971.684, 361851.801 40...
# 4    POLYGON ((358668.063 410971.684, 361851.801 40...
# ..                                                 ...
# 531  POLYGON ((402525.503 401459.003, 400905.596 39...
# 532  POLYGON ((358668.063 410971.684, 361851.801 40...
# 533  POLYGON ((384375.197 404714.801, 385603.299 40...
# 534  POLYGON ((384375.197 404714.801, 385603.299 40...
# 535  POLYGON ((375025.76 414990.104, 374998.996 413...
#
#                                 SiteRef_y  No. Sites in 1km
# 0                                Big Wood                 0
# 1                   Winstanley Hall Woods                 1
# 2             Ackhurst Lane Sand Workings                 3
# 3                             Abbey Lakes                 6
# 4                           Wetland by M6                 1
# ..                                    ...               ...
# 531  Mill Race & Pasture at Haughton Dale                 8
# 532                         Three Sisters                 2
# 533                         Nan Nook Wood                 7
# 534                              Big Wood                10
# 535                     Bank Wood & Marsh                11
#
# [536 rows x 9 columns]

# %%
joined_two_At_Risk = joined_two[joined_two["No. Sites in 1km"]>14]

# %%
joined_two_At_Risk
# Out:
#                           Category      LAName  \
# 5    Site of Biological Importance       Wigan
# 19   Site of Biological Importance       Wigan
# 24   Site of Biological Importance       Wigan
# 43   Site of Biological Importance      Bolton
# 51   Site of Biological Importance        Bury
# 66   Site of Biological Importance     Salford
# 67   Site of Biological Importance     Salford
# 68   Site of Biological Importance     Salford
# 70   Site of Biological Importance     Salford
# 80   Site of Biological Importance  Manchester
# 86   Site of Biological Importance      Oldham
# 108  Site of Biological Importance    Trafford
# 111  Site of Biological Importance    Trafford
# 133  Site of Biological Importance    Tameside
# 139  Site of Biological Importance    Tameside
# 169  Site of Biological Importance    Trafford
# 189  Site of Biological Importance    Rochdale
# 206  Site of Biological Importance    Rochdale
# 223  Site of Biological Importance      Bolton
# 259  Site of Biological Importance  Manchester
# 265  Site of Biological Importance    Trafford
# 272  Site of Biological Importance  Manchester
# 317  Site of Biological Importance    Tameside
# 327  Site of Biological Importance       Wigan
# 328  Site of Biological Importance  Manchester
# 336  Site of Biological Importance      Oldham
# 345  Site of Biological Importance    Trafford
# 351  Site of Biological Importance      Bolton
# 359  Site of Biological Importance        Bury
# 365  Site of Biological Importance  Manchester
# 366  Site of Biological Importance  Manchester
# 393  Site of Biological Importance      Bolton
# 406  Site of Biological Importance      Oldham
# 408  Site of Biological Importance    Tameside
# 412  Site of Biological Importance  Manchester
# 427  Site of Biological Importance      Bolton
# 433  Site of Biological Importance        Bury
# 444  Site of Biological Importance    Trafford
# 456  Site of Biological Importance  Manchester
# 465  Site of Biological Importance        Bury
# 474  Site of Biological Importance     Salford
# 480  Site of Biological Importance        Bury
# 485  Site of Biological Importance      Oldham
# 495  Site of Biological Importance  Manchester
# 501  Site of Biological Importance  Manchester
#
#                                              SiteRef_x  \
# 5                               Ponds at Primrose Lane
# 19                           Meadow near Kirkless Hall
# 24                                           Firs Park
# 43                                  Bradford Reservoir
# 51                              Wetland near Radcliffe
# 66                                   Bridgewater Canal
# 67                                       Three Sisters
# 68                               Salford Quays (North)
# 70                                Blackleach Reservoir
# 80                                        Clayton Vale
# 86                                              Dacres
# 108                           Bentley & Tomfield Banks
# 111                              Salford Quays (South)
# 133                                   Puddle Clay Pits
# 139                                     Gower Hey Wood
# 169                          Wetland Near Balfour Road
# 189                                Scowcroft Reservoir
# 206                                  Queen's Park Lake
# 223              Smith Road Reservoirs & Raikes Clough
# 259                            Reservoirs at Harpurhey
# 265                                   Devisdale Meadow
# 272                                 Bank Bridge Meadow
# 317                                Ashton Canal (East)
# 327                                  Amberswood Common
# 328                                  Broadhurst Clough
# 336  Rochdale Canal - Lock at Scowcroft Farm to Sto...
# 345                                 King George V Pool
# 351                                       Crown Clough
# 359                                           Townside
# 365                                Ashton Canal (West)
# 366  Rochdale Canal - Stott's Lane to Ducie Street ...
# 393                                        Temple Road
# 406                                          Shaw Side
# 408                                 Stamford Park Lake
# 412                                Boggart Hole Clough
# 427                                         Moses Gate
# 433                                     Crow Lumb Wood
# 444                              Trafford Ecology Park
# 456                                     Boardman Brook
# 465             Manchester, Bolton & Bury Canal (East)
# 474                                       River Irwell
# 480                          Reservoirs at Chapelfield
# 485                            Ponds at Cowlishaw Farm
# 495                              Bowker Vale Reservoir
# 501                                     Moston Fairway
#
#                                           SBI_Location  \
# 5    POLYGON ((355587.865 410547.072, 355609.634 41...
# 19   POLYGON ((359875.249 406253.168, 359867.86 406...
# 24   POLYGON ((364518.048 400681.669, 364529.747 40...
# 43   POLYGON ((372273.276 407679.975, 372262.476 40...
# 51   POLYGON ((378742.219 407785.863, 378694.906 40...
# 66   POLYGON ((376376.965 399472.474, 376398.202 39...
# 67   POLYGON ((377597.954 399827.739, 377624.402 39...
# 68   POLYGON ((380483.893 397023.667, 380504.568 39...
# 70   POLYGON ((373653.338 403890.027, 373654.283 40...
# 80   MULTIPOLYGON (((388092.022 399403.207, 388099....
# 86   POLYGON ((398733.589 403899.581, 398741.645 40...
# 108  POLYGON ((378175.899 385203.318, 378175.737 38...
# 111  POLYGON ((380483.893 397023.667, 380541.04 396...
# 133  POLYGON ((397938.567 402624.027, 397948.432 40...
# 139  POLYGON ((394167.942 394172.026, 394170.256 39...
# 169  POLYGON ((377086.904 389511.299, 377128.778 38...
# 189  POLYGON ((388130.517 406603.417, 388131.993 40...
# 206  POLYGON ((385987.444 411731.879, 386018.146 41...
# 223  POLYGON ((373499.122 407460.589, 373515.806 40...
# 259  MULTIPOLYGON (((385432.136 401765.792, 385427....
# 265  POLYGON ((375499.146 387479.609, 375488.606 38...
# 272  POLYGON ((387302.261 399153.162, 387313.648 39...
# 317  POLYGON ((393510.395 398453.363, 393516.529 39...
# 327  MULTIPOLYGON (((361087.118 403657.732, 361063....
# 328  POLYGON ((387796.477 401351.484, 387804.821 40...
# 336  POLYGON ((389862.161 402504.014, 389861.378 40...
# 345  POLYGON ((377442.626 387951.459, 377452.602 38...
# 351  POLYGON ((363365.066 411787.346, 363343.25 411...
# 359  POLYGON ((380644.447 410264.652, 380637.595 41...
# 365  POLYGON ((389110.896 398002.202, 389110.624 39...
# 366  POLYGON ((388578.447 400697.631, 388553.225 40...
# 393  POLYGON ((370541.84 411382.612, 370568.446 411...
# 406  POLYGON ((394177.89 408243.847, 394171.478 408...
# 408  POLYGON ((395647.133 399560.211, 395634.683 39...
# 412  POLYGON ((386802.469 402885.453, 386836.978 40...
# 427  POLYGON ((374420.151 406612.698, 374420.151 40...
# 433  POLYGON ((379130.002 416389.149, 379129.854 41...
# 444  POLYGON ((379352.807 397387.947, 379350.302 39...
# 456  POLYGON ((386253.397 404708.603, 386253.317 40...
# 465  MULTIPOLYGON (((378159.227 407469.529, 378161....
# 474  POLYGON ((380855.74 400908, 380833.049 400952....
# 480  POLYGON ((378984.749 406094.496, 378984.601 40...
# 485  MULTIPOLYGON (((392837.76 408744.463, 392838.3...
# 495  MULTIPOLYGON (((383796.323 403133.857, 383811....
# 501  POLYGON ((388609.605 402302.351, 388608.871 40...
#
#                           centroid   ref  \
# 5    POINT (355707.163 410520.464)  4362
# 19   POINT (360000.375 406294.412)  4376
# 24   POINT (364488.113 400600.946)  4381
# 43    POINT (372190.425 407595.22)  4400
# 51   POINT (378744.817 407815.339)  4408
# 66    POINT (376333.494 398534.86)  4423
# 67   POINT (377636.164 399700.487)  4424
# 68   POINT (380794.224 396941.683)  4425
# 70   POINT (373993.954 404068.892)  4427
# 80   POINT (388277.776 399437.268)  4437
# 86   POINT (398909.816 403978.854)  4443
# 108  POINT (378395.946 385314.884)  4465
# 111  POINT (380756.383 396836.056)  4468
# 133   POINT (398129.29 402832.215)  4490
# 139  POINT (394213.052 394092.183)  4496
# 169   POINT (377119.59 389446.484)  4526
# 189  POINT (388186.567 406627.903)  4546
# 206  POINT (386038.255 411640.494)  4563
# 223  POINT (373304.022 407437.941)  4580
# 259  POINT (385443.515 401656.633)  4616
# 265  POINT (375508.306 387523.737)  4622
# 272  POINT (387423.683 399200.371)  4629
# 317  POINT (391415.533 397781.433)  4674
# 327  POINT (360368.918 404017.052)  4684
# 328  POINT (387839.439 401723.582)  4685
# 336  POINT (389213.816 403660.323)  4693
# 345  POINT (377586.755 387945.708)  4702
# 351  POINT (363265.607 411676.727)  4708
# 359  POINT (380530.067 410304.034)  4716
# 365  POINT (387018.446 398443.835)  4722
# 366  POINT (386480.007 399568.197)  4723
# 393  POINT (370504.873 411321.736)  4750
# 406  POINT (394024.986 408475.516)  4763
# 408  POINT (395650.298 399507.093)  4765
# 412  POINT (386588.923 402566.271)  4769
# 427   POINT (374208.12 406614.742)  4784
# 433  POINT (379094.671 416218.161)  4790
# 444  POINT (379212.416 397407.091)  4801
# 456  POINT (385900.085 404992.843)  4813
# 465  POINT (377990.814 407585.338)  4822
# 474  POINT (381802.932 400428.987)  4831
# 480  POINT (378967.355 406195.683)  4837
# 485  POINT (392918.186 408754.106)  4842
# 495  POINT (383930.406 403005.688)  4852
# 501  POINT (388383.182 401754.226)  4858
#
#                                        Local Authority  \
# 5    POLYGON ((358668.063 410971.684, 361851.801 40...
# 19   POLYGON ((358668.063 410971.684, 361851.801 40...
# 24   POLYGON ((358668.063 410971.684, 361851.801 40...
# 43   POLYGON ((375025.76 414990.104, 374998.996 413...
# 51   POLYGON ((382118.504 413135.864, 383878.498 41...
# 66   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 67   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 68   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 70   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 80   POLYGON ((384375.197 404714.801, 385603.299 40...
# 86   POLYGON ((399470.898 413357.697, 403891.1 4072...
# 108  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 111  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 133  POLYGON ((402525.503 401459.003, 400905.596 39...
# 139  POLYGON ((402525.503 401459.003, 400905.596 39...
# 169  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 189  POLYGON ((398323.804 414179.902, 397726.598 41...
# 206  POLYGON ((398323.804 414179.902, 397726.598 41...
# 223  POLYGON ((375025.76 414990.104, 374998.996 413...
# 259  POLYGON ((384375.197 404714.801, 385603.299 40...
# 265  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 272  POLYGON ((384375.197 404714.801, 385603.299 40...
# 317  POLYGON ((402525.503 401459.003, 400905.596 39...
# 327  POLYGON ((358668.063 410971.684, 361851.801 40...
# 328  POLYGON ((384375.197 404714.801, 385603.299 40...
# 336  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 345  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 351  POLYGON ((375025.76 414990.104, 374998.996 413...
# 359  POLYGON ((382118.504 413135.864, 383878.498 41...
# 365  POLYGON ((384375.197 404714.801, 385603.299 40...
# 366  POLYGON ((384375.197 404714.801, 385603.299 40...
# 393  POLYGON ((375025.76 414990.104, 374998.996 413...
# 406  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 408  POLYGON ((402525.503 401459.003, 400905.596 39...
# 412  POLYGON ((384375.197 404714.801, 385603.299 40...
# 427  POLYGON ((375025.76 414990.104, 374998.996 413...
# 433  POLYGON ((382118.504 413135.864, 383878.498 41...
# 444  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 456  POLYGON ((384375.197 404714.801, 385603.299 40...
# 465  POLYGON ((382118.504 413135.864, 383878.498 41...
# 474  POLYGON ((377681.197 404158.1, 379515.5 403434...
# 480  POLYGON ((382118.504 413135.864, 383878.498 41...
# 485  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 495  POLYGON ((384375.197 404714.801, 385603.299 40...
# 501  POLYGON ((384375.197 404714.801, 385603.299 40...
#
#                                              SiteRef_y  No. Sites in 1km
# 5                               Ponds at Primrose Lane                15
# 19                           Meadow near Kirkless Hall                15
# 24                                           Firs Park                16
# 43                                  Bradford Reservoir                19
# 51                              Wetland near Radcliffe                37
# 66                                   Bridgewater Canal                21
# 67                                       Three Sisters                15
# 68                               Salford Quays (North)                33
# 70                                Blackleach Reservoir                15
# 80                                        Clayton Vale                24
# 86                                              Dacres                15
# 108                           Bentley & Tomfield Banks                21
# 111                              Salford Quays (South)                38
# 133                                   Puddle Clay Pits                21
# 139                                     Gower Hey Wood                16
# 169                          Wetland Near Balfour Road                20
# 189                                Scowcroft Reservoir                23
# 206                                  Queen's Park Lake                17
# 223              Smith Road Reservoirs & Raikes Clough                15
# 259                            Reservoirs at Harpurhey                25
# 265                                   Devisdale Meadow                16
# 272                                 Bank Bridge Meadow                16
# 317                                Ashton Canal (East)                15
# 327                                  Amberswood Common                16
# 328                                  Broadhurst Clough                24
# 336  Rochdale Canal - Lock at Scowcroft Farm to Sto...                15
# 345                                 King George V Pool                29
# 351                                       Crown Clough                17
# 359                                           Townside                37
# 365                                Ashton Canal (West)                19
# 366  Rochdale Canal - Stott's Lane to Ducie Street ...                20
# 393                                        Temple Road                30
# 406                                          Shaw Side                20
# 408                                 Stamford Park Lake                18
# 412                                Boggart Hole Clough                19
# 427                                         Moses Gate                18
# 433                                     Crow Lumb Wood                17
# 444                              Trafford Ecology Park                20
# 456                                     Boardman Brook                18
# 465             Manchester, Bolton & Bury Canal (East)                31
# 474                                       River Irwell                18
# 480                          Reservoirs at Chapelfield                16
# 485                            Ponds at Cowlishaw Farm                17
# 495                              Bowker Vale Reservoir                18
# 501                                     Moston Fairway                24

# %%
len(joined_two_At_Risk)
# Out:
# 45

# %%
joined_two
# Out:
#                           Category      LAName  \
# 0    Site of Biological Importance       Wigan
# 1    Site of Biological Importance       Wigan
# 2    Site of Biological Importance       Wigan
# 3    Site of Biological Importance       Wigan
# 4    Site of Biological Importance       Wigan
# ..                             ...         ...
# 531  Site of Biological Importance    Tameside
# 532  Site of Biological Importance       Wigan
# 533  Site of Biological Importance  Manchester
# 534  Site of Biological Importance  Manchester
# 535  Site of Biological Importance      Bolton
#
#                                 SiteRef_x  \
# 0                                Big Wood
# 1                   Winstanley Hall Woods
# 2             Ackhurst Lane Sand Workings
# 3                             Abbey Lakes
# 4                           Wetland by M6
# ..                                    ...
# 531  Mill Race & Pasture at Haughton Dale
# 532                         Three Sisters
# 533                         Nan Nook Wood
# 534                              Big Wood
# 535                     Bank Wood & Marsh
#
#                                           SBI_Location  \
# 0    POLYGON ((353649.752 410536.46, 353660.55 4105...
# 1    MULTIPOLYGON (((354300.461 403639.988, 354318....
# 2    POLYGON ((354320.268 407088.639, 354329.097 40...
# 3    POLYGON ((352622.159 404628.83, 352625.623 404...
# 4    MULTIPOLYGON (((354408.45 411806.416, 354430.9...
# ..                                                 ...
# 531  MULTIPOLYGON (((393687.128 393384.895, 393682....
# 532  POLYGON ((357928.939 401185.293, 357957.618 40...
# 533  POLYGON ((381158.403 390125.048, 381156.853 39...
# 534  MULTIPOLYGON (((383512.797 386267.952, 383512....
# 535  POLYGON ((369344.075 408685.587, 369329.313 40...
#
#                           centroid   ref  \
# 0    POINT (353331.975 410159.462)  4357
# 1    POINT (354500.103 403252.365)  4358
# 2     POINT (354217.366 407048.76)  4359
# 3     POINT (352671.79 404738.385)  4360
# 4     POINT (354504.673 411797.58)  4361
# ..                             ...   ...
# 531  POINT (393841.341 393512.227)  4888
# 532  POINT (358367.769 401012.636)  4889
# 533  POINT (380888.856 390037.976)  4890
# 534  POINT (383309.435 386406.658)  4891
# 535  POINT (368971.201 408737.581)  4892
#
#                                        Local Authority  \
# 0    POLYGON ((358668.063 410971.684, 361851.801 40...
# 1    POLYGON ((358668.063 410971.684, 361851.801 40...
# 2    POLYGON ((358668.063 410971.684, 361851.801 40...
# 3    POLYGON ((358668.063 410971.684, 361851.801 40...
# 4    POLYGON ((358668.063 410971.684, 361851.801 40...
# ..                                                 ...
# 531  POLYGON ((402525.503 401459.003, 400905.596 39...
# 532  POLYGON ((358668.063 410971.684, 361851.801 40...
# 533  POLYGON ((384375.197 404714.801, 385603.299 40...
# 534  POLYGON ((384375.197 404714.801, 385603.299 40...
# 535  POLYGON ((375025.76 414990.104, 374998.996 413...
#
#                                 SiteRef_y  No. Sites in 1km
# 0                                Big Wood                 0
# 1                   Winstanley Hall Woods                 1
# 2             Ackhurst Lane Sand Workings                 3
# 3                             Abbey Lakes                 6
# 4                           Wetland by M6                 1
# ..                                    ...               ...
# 531  Mill Race & Pasture at Haughton Dale                 8
# 532                         Three Sisters                 2
# 533                         Nan Nook Wood                 7
# 534                              Big Wood                10
# 535                     Bank Wood & Marsh                11
#
# [536 rows x 9 columns]

# %%
#this gives the number of sbi's in eahc local authority that is "at risk" according to the current threshhold.

joined_two_At_Risk.groupby("LAName")[["No. Sites in 1km"]].sum()
# Out:
#             No. Sites in 1km
# LAName
# Bolton                    99
# Bury                     138
# Manchester               207
# Oldham                    67
# Rochdale                  40
# Salford                  102
# Tameside                  70
# Trafford                 144
# Wigan                     62

# %%
joined_two_At_Risk
# Out:
#                           Category      LAName  \
# 5    Site of Biological Importance       Wigan
# 19   Site of Biological Importance       Wigan
# 24   Site of Biological Importance       Wigan
# 43   Site of Biological Importance      Bolton
# 51   Site of Biological Importance        Bury
# 66   Site of Biological Importance     Salford
# 67   Site of Biological Importance     Salford
# 68   Site of Biological Importance     Salford
# 70   Site of Biological Importance     Salford
# 80   Site of Biological Importance  Manchester
# 86   Site of Biological Importance      Oldham
# 108  Site of Biological Importance    Trafford
# 111  Site of Biological Importance    Trafford
# 133  Site of Biological Importance    Tameside
# 139  Site of Biological Importance    Tameside
# 169  Site of Biological Importance    Trafford
# 189  Site of Biological Importance    Rochdale
# 206  Site of Biological Importance    Rochdale
# 223  Site of Biological Importance      Bolton
# 259  Site of Biological Importance  Manchester
# 265  Site of Biological Importance    Trafford
# 272  Site of Biological Importance  Manchester
# 317  Site of Biological Importance    Tameside
# 327  Site of Biological Importance       Wigan
# 328  Site of Biological Importance  Manchester
# 336  Site of Biological Importance      Oldham
# 345  Site of Biological Importance    Trafford
# 351  Site of Biological Importance      Bolton
# 359  Site of Biological Importance        Bury
# 365  Site of Biological Importance  Manchester
# 366  Site of Biological Importance  Manchester
# 393  Site of Biological Importance      Bolton
# 406  Site of Biological Importance      Oldham
# 408  Site of Biological Importance    Tameside
# 412  Site of Biological Importance  Manchester
# 427  Site of Biological Importance      Bolton
# 433  Site of Biological Importance        Bury
# 444  Site of Biological Importance    Trafford
# 456  Site of Biological Importance  Manchester
# 465  Site of Biological Importance        Bury
# 474  Site of Biological Importance     Salford
# 480  Site of Biological Importance        Bury
# 485  Site of Biological Importance      Oldham
# 495  Site of Biological Importance  Manchester
# 501  Site of Biological Importance  Manchester
#
#                                              SiteRef_x  \
# 5                               Ponds at Primrose Lane
# 19                           Meadow near Kirkless Hall
# 24                                           Firs Park
# 43                                  Bradford Reservoir
# 51                              Wetland near Radcliffe
# 66                                   Bridgewater Canal
# 67                                       Three Sisters
# 68                               Salford Quays (North)
# 70                                Blackleach Reservoir
# 80                                        Clayton Vale
# 86                                              Dacres
# 108                           Bentley & Tomfield Banks
# 111                              Salford Quays (South)
# 133                                   Puddle Clay Pits
# 139                                     Gower Hey Wood
# 169                          Wetland Near Balfour Road
# 189                                Scowcroft Reservoir
# 206                                  Queen's Park Lake
# 223              Smith Road Reservoirs & Raikes Clough
# 259                            Reservoirs at Harpurhey
# 265                                   Devisdale Meadow
# 272                                 Bank Bridge Meadow
# 317                                Ashton Canal (East)
# 327                                  Amberswood Common
# 328                                  Broadhurst Clough
# 336  Rochdale Canal - Lock at Scowcroft Farm to Sto...
# 345                                 King George V Pool
# 351                                       Crown Clough
# 359                                           Townside
# 365                                Ashton Canal (West)
# 366  Rochdale Canal - Stott's Lane to Ducie Street ...
# 393                                        Temple Road
# 406                                          Shaw Side
# 408                                 Stamford Park Lake
# 412                                Boggart Hole Clough
# 427                                         Moses Gate
# 433                                     Crow Lumb Wood
# 444                              Trafford Ecology Park
# 456                                     Boardman Brook
# 465             Manchester, Bolton & Bury Canal (East)
# 474                                       River Irwell
# 480                          Reservoirs at Chapelfield
# 485                            Ponds at Cowlishaw Farm
# 495                              Bowker Vale Reservoir
# 501                                     Moston Fairway
#
#                                           SBI_Location  \
# 5    POLYGON ((355587.865 410547.072, 355609.634 41...
# 19   POLYGON ((359875.249 406253.168, 359867.86 406...
# 24   POLYGON ((364518.048 400681.669, 364529.747 40...
# 43   POLYGON ((372273.276 407679.975, 372262.476 40...
# 51   POLYGON ((378742.219 407785.863, 378694.906 40...
# 66   POLYGON ((376376.965 399472.474, 376398.202 39...
# 67   POLYGON ((377597.954 399827.739, 377624.402 39...
# 68   POLYGON ((380483.893 397023.667, 380504.568 39...
# 70   POLYGON ((373653.338 403890.027, 373654.283 40...
# 80   MULTIPOLYGON (((388092.022 399403.207, 388099....
# 86   POLYGON ((398733.589 403899.581, 398741.645 40...
# 108  POLYGON ((378175.899 385203.318, 378175.737 38...
# 111  POLYGON ((380483.893 397023.667, 380541.04 396...
# 133  POLYGON ((397938.567 402624.027, 397948.432 40...
# 139  POLYGON ((394167.942 394172.026, 394170.256 39...
# 169  POLYGON ((377086.904 389511.299, 377128.778 38...
# 189  POLYGON ((388130.517 406603.417, 388131.993 40...
# 206  POLYGON ((385987.444 411731.879, 386018.146 41...
# 223  POLYGON ((373499.122 407460.589, 373515.806 40...
# 259  MULTIPOLYGON (((385432.136 401765.792, 385427....
# 265  POLYGON ((375499.146 387479.609, 375488.606 38...
# 272  POLYGON ((387302.261 399153.162, 387313.648 39...
# 317  POLYGON ((393510.395 398453.363, 393516.529 39...
# 327  MULTIPOLYGON (((361087.118 403657.732, 361063....
# 328  POLYGON ((387796.477 401351.484, 387804.821 40...
# 336  POLYGON ((389862.161 402504.014, 389861.378 40...
# 345  POLYGON ((377442.626 387951.459, 377452.602 38...
# 351  POLYGON ((363365.066 411787.346, 363343.25 411...
# 359  POLYGON ((380644.447 410264.652, 380637.595 41...
# 365  POLYGON ((389110.896 398002.202, 389110.624 39...
# 366  POLYGON ((388578.447 400697.631, 388553.225 40...
# 393  POLYGON ((370541.84 411382.612, 370568.446 411...
# 406  POLYGON ((394177.89 408243.847, 394171.478 408...
# 408  POLYGON ((395647.133 399560.211, 395634.683 39...
# 412  POLYGON ((386802.469 402885.453, 386836.978 40...
# 427  POLYGON ((374420.151 406612.698, 374420.151 40...
# 433  POLYGON ((379130.002 416389.149, 379129.854 41...
# 444  POLYGON ((379352.807 397387.947, 379350.302 39...
# 456  POLYGON ((386253.397 404708.603, 386253.317 40...
# 465  MULTIPOLYGON (((378159.227 407469.529, 378161....
# 474  POLYGON ((380855.74 400908, 380833.049 400952....
# 480  POLYGON ((378984.749 406094.496, 378984.601 40...
# 485  MULTIPOLYGON (((392837.76 408744.463, 392838.3...
# 495  MULTIPOLYGON (((383796.323 403133.857, 383811....
# 501  POLYGON ((388609.605 402302.351, 388608.871 40...
#
#                           centroid   ref  \
# 5    POINT (355707.163 410520.464)  4362
# 19   POINT (360000.375 406294.412)  4376
# 24   POINT (364488.113 400600.946)  4381
# 43    POINT (372190.425 407595.22)  4400
# 51   POINT (378744.817 407815.339)  4408
# 66    POINT (376333.494 398534.86)  4423
# 67   POINT (377636.164 399700.487)  4424
# 68   POINT (380794.224 396941.683)  4425
# 70   POINT (373993.954 404068.892)  4427
# 80   POINT (388277.776 399437.268)  4437
# 86   POINT (398909.816 403978.854)  4443
# 108  POINT (378395.946 385314.884)  4465
# 111  POINT (380756.383 396836.056)  4468
# 133   POINT (398129.29 402832.215)  4490
# 139  POINT (394213.052 394092.183)  4496
# 169   POINT (377119.59 389446.484)  4526
# 189  POINT (388186.567 406627.903)  4546
# 206  POINT (386038.255 411640.494)  4563
# 223  POINT (373304.022 407437.941)  4580
# 259  POINT (385443.515 401656.633)  4616
# 265  POINT (375508.306 387523.737)  4622
# 272  POINT (387423.683 399200.371)  4629
# 317  POINT (391415.533 397781.433)  4674
# 327  POINT (360368.918 404017.052)  4684
# 328  POINT (387839.439 401723.582)  4685
# 336  POINT (389213.816 403660.323)  4693
# 345  POINT (377586.755 387945.708)  4702
# 351  POINT (363265.607 411676.727)  4708
# 359  POINT (380530.067 410304.034)  4716
# 365  POINT (387018.446 398443.835)  4722
# 366  POINT (386480.007 399568.197)  4723
# 393  POINT (370504.873 411321.736)  4750
# 406  POINT (394024.986 408475.516)  4763
# 408  POINT (395650.298 399507.093)  4765
# 412  POINT (386588.923 402566.271)  4769
# 427   POINT (374208.12 406614.742)  4784
# 433  POINT (379094.671 416218.161)  4790
# 444  POINT (379212.416 397407.091)  4801
# 456  POINT (385900.085 404992.843)  4813
# 465  POINT (377990.814 407585.338)  4822
# 474  POINT (381802.932 400428.987)  4831
# 480  POINT (378967.355 406195.683)  4837
# 485  POINT (392918.186 408754.106)  4842
# 495  POINT (383930.406 403005.688)  4852
# 501  POINT (388383.182 401754.226)  4858
#
#                                        Local Authority  \
# 5    POLYGON ((358668.063 410971.684, 361851.801 40...
# 19   POLYGON ((358668.063 410971.684, 361851.801 40...
# 24   POLYGON ((358668.063 410971.684, 361851.801 40...
# 43   POLYGON ((375025.76 414990.104, 374998.996 413...
# 51   POLYGON ((382118.504 413135.864, 383878.498 41...
# 66   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 67   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 68   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 70   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 80   POLYGON ((384375.197 404714.801, 385603.299 40...
# 86   POLYGON ((399470.898 413357.697, 403891.1 4072...
# 108  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 111  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 133  POLYGON ((402525.503 401459.003, 400905.596 39...
# 139  POLYGON ((402525.503 401459.003, 400905.596 39...
# 169  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 189  POLYGON ((398323.804 414179.902, 397726.598 41...
# 206  POLYGON ((398323.804 414179.902, 397726.598 41...
# 223  POLYGON ((375025.76 414990.104, 374998.996 413...
# 259  POLYGON ((384375.197 404714.801, 385603.299 40...
# 265  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 272  POLYGON ((384375.197 404714.801, 385603.299 40...
# 317  POLYGON ((402525.503 401459.003, 400905.596 39...
# 327  POLYGON ((358668.063 410971.684, 361851.801 40...
# 328  POLYGON ((384375.197 404714.801, 385603.299 40...
# 336  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 345  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 351  POLYGON ((375025.76 414990.104, 374998.996 413...
# 359  POLYGON ((382118.504 413135.864, 383878.498 41...
# 365  POLYGON ((384375.197 404714.801, 385603.299 40...
# 366  POLYGON ((384375.197 404714.801, 385603.299 40...
# 393  POLYGON ((375025.76 414990.104, 374998.996 413...
# 406  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 408  POLYGON ((402525.503 401459.003, 400905.596 39...
# 412  POLYGON ((384375.197 404714.801, 385603.299 40...
# 427  POLYGON ((375025.76 414990.104, 374998.996 413...
# 433  POLYGON ((382118.504 413135.864, 383878.498 41...
# 444  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 456  POLYGON ((384375.197 404714.801, 385603.299 40...
# 465  POLYGON ((382118.504 413135.864, 383878.498 41...
# 474  POLYGON ((377681.197 404158.1, 379515.5 403434...
# 480  POLYGON ((382118.504 413135.864, 383878.498 41...
# 485  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 495  POLYGON ((384375.197 404714.801, 385603.299 40...
# 501  POLYGON ((384375.197 404714.801, 385603.299 40...
#
#                                              SiteRef_y  No. Sites in 1km
# 5                               Ponds at Primrose Lane                15
# 19                           Meadow near Kirkless Hall                15
# 24                                           Firs Park                16
# 43                                  Bradford Reservoir                19
# 51                              Wetland near Radcliffe                37
# 66                                   Bridgewater Canal                21
# 67                                       Three Sisters                15
# 68                               Salford Quays (North)                33
# 70                                Blackleach Reservoir                15
# 80                                        Clayton Vale                24
# 86                                              Dacres                15
# 108                           Bentley & Tomfield Banks                21
# 111                              Salford Quays (South)                38
# 133                                   Puddle Clay Pits                21
# 139                                     Gower Hey Wood                16
# 169                          Wetland Near Balfour Road                20
# 189                                Scowcroft Reservoir                23
# 206                                  Queen's Park Lake                17
# 223              Smith Road Reservoirs & Raikes Clough                15
# 259                            Reservoirs at Harpurhey                25
# 265                                   Devisdale Meadow                16
# 272                                 Bank Bridge Meadow                16
# 317                                Ashton Canal (East)                15
# 327                                  Amberswood Common                16
# 328                                  Broadhurst Clough                24
# 336  Rochdale Canal - Lock at Scowcroft Farm to Sto...                15
# 345                                 King George V Pool                29
# 351                                       Crown Clough                17
# 359                                           Townside                37
# 365                                Ashton Canal (West)                19
# 366  Rochdale Canal - Stott's Lane to Ducie Street ...                20
# 393                                        Temple Road                30
# 406                                          Shaw Side                20
# 408                                 Stamford Park Lake                18
# 412                                Boggart Hole Clough                19
# 427                                         Moses Gate                18
# 433                                     Crow Lumb Wood                17
# 444                              Trafford Ecology Park                20
# 456                                     Boardman Brook                18
# 465             Manchester, Bolton & Bury Canal (East)                31
# 474                                       River Irwell                18
# 480                          Reservoirs at Chapelfield                16
# 485                            Ponds at Cowlishaw Farm                17
# 495                              Bowker Vale Reservoir                18
# 501                                     Moston Fairway                24

# %%
# Step 1: Group by LAName and calculate the sum
agg = joined_two_At_Risk.groupby("LAName")[["No. Sites in 1km"]].sum()
agg = agg.rename(columns={"No. Sites in 1km": "Total Sites in 1km (LA)"})

# Step 2: Merge the aggregated data back into the original DataFrame
joined_two_At_Risk = joined_two_At_Risk.merge(agg, on="LAName", how="left")

# %%
joined_two_At_Risk
# Out:
#                          Category      LAName  \
# 0   Site of Biological Importance       Wigan
# 1   Site of Biological Importance       Wigan
# 2   Site of Biological Importance       Wigan
# 3   Site of Biological Importance      Bolton
# 4   Site of Biological Importance        Bury
# 5   Site of Biological Importance     Salford
# 6   Site of Biological Importance     Salford
# 7   Site of Biological Importance     Salford
# 8   Site of Biological Importance     Salford
# 9   Site of Biological Importance  Manchester
# 10  Site of Biological Importance      Oldham
# 11  Site of Biological Importance    Trafford
# 12  Site of Biological Importance    Trafford
# 13  Site of Biological Importance    Tameside
# 14  Site of Biological Importance    Tameside
# 15  Site of Biological Importance    Trafford
# 16  Site of Biological Importance    Rochdale
# 17  Site of Biological Importance    Rochdale
# 18  Site of Biological Importance      Bolton
# 19  Site of Biological Importance  Manchester
# 20  Site of Biological Importance    Trafford
# 21  Site of Biological Importance  Manchester
# 22  Site of Biological Importance    Tameside
# 23  Site of Biological Importance       Wigan
# 24  Site of Biological Importance  Manchester
# 25  Site of Biological Importance      Oldham
# 26  Site of Biological Importance    Trafford
# 27  Site of Biological Importance      Bolton
# 28  Site of Biological Importance        Bury
# 29  Site of Biological Importance  Manchester
# 30  Site of Biological Importance  Manchester
# 31  Site of Biological Importance      Bolton
# 32  Site of Biological Importance      Oldham
# 33  Site of Biological Importance    Tameside
# 34  Site of Biological Importance  Manchester
# 35  Site of Biological Importance      Bolton
# 36  Site of Biological Importance        Bury
# 37  Site of Biological Importance    Trafford
# 38  Site of Biological Importance  Manchester
# 39  Site of Biological Importance        Bury
# 40  Site of Biological Importance     Salford
# 41  Site of Biological Importance        Bury
# 42  Site of Biological Importance      Oldham
# 43  Site of Biological Importance  Manchester
# 44  Site of Biological Importance  Manchester
#
#                                             SiteRef_x  \
# 0                              Ponds at Primrose Lane
# 1                           Meadow near Kirkless Hall
# 2                                           Firs Park
# 3                                  Bradford Reservoir
# 4                              Wetland near Radcliffe
# 5                                   Bridgewater Canal
# 6                                       Three Sisters
# 7                               Salford Quays (North)
# 8                                Blackleach Reservoir
# 9                                        Clayton Vale
# 10                                             Dacres
# 11                           Bentley & Tomfield Banks
# 12                              Salford Quays (South)
# 13                                   Puddle Clay Pits
# 14                                     Gower Hey Wood
# 15                          Wetland Near Balfour Road
# 16                                Scowcroft Reservoir
# 17                                  Queen's Park Lake
# 18              Smith Road Reservoirs & Raikes Clough
# 19                            Reservoirs at Harpurhey
# 20                                   Devisdale Meadow
# 21                                 Bank Bridge Meadow
# 22                                Ashton Canal (East)
# 23                                  Amberswood Common
# 24                                  Broadhurst Clough
# 25  Rochdale Canal - Lock at Scowcroft Farm to Sto...
# 26                                 King George V Pool
# 27                                       Crown Clough
# 28                                           Townside
# 29                                Ashton Canal (West)
# 30  Rochdale Canal - Stott's Lane to Ducie Street ...
# 31                                        Temple Road
# 32                                          Shaw Side
# 33                                 Stamford Park Lake
# 34                                Boggart Hole Clough
# 35                                         Moses Gate
# 36                                     Crow Lumb Wood
# 37                              Trafford Ecology Park
# 38                                     Boardman Brook
# 39             Manchester, Bolton & Bury Canal (East)
# 40                                       River Irwell
# 41                          Reservoirs at Chapelfield
# 42                            Ponds at Cowlishaw Farm
# 43                              Bowker Vale Reservoir
# 44                                     Moston Fairway
#
#                                          SBI_Location  \
# 0   POLYGON ((355587.865 410547.072, 355609.634 41...
# 1   POLYGON ((359875.249 406253.168, 359867.86 406...
# 2   POLYGON ((364518.048 400681.669, 364529.747 40...
# 3   POLYGON ((372273.276 407679.975, 372262.476 40...
# 4   POLYGON ((378742.219 407785.863, 378694.906 40...
# 5   POLYGON ((376376.965 399472.474, 376398.202 39...
# 6   POLYGON ((377597.954 399827.739, 377624.402 39...
# 7   POLYGON ((380483.893 397023.667, 380504.568 39...
# 8   POLYGON ((373653.338 403890.027, 373654.283 40...
# 9   MULTIPOLYGON (((388092.022 399403.207, 388099....
# 10  POLYGON ((398733.589 403899.581, 398741.645 40...
# 11  POLYGON ((378175.899 385203.318, 378175.737 38...
# 12  POLYGON ((380483.893 397023.667, 380541.04 396...
# 13  POLYGON ((397938.567 402624.027, 397948.432 40...
# 14  POLYGON ((394167.942 394172.026, 394170.256 39...
# 15  POLYGON ((377086.904 389511.299, 377128.778 38...
# 16  POLYGON ((388130.517 406603.417, 388131.993 40...
# 17  POLYGON ((385987.444 411731.879, 386018.146 41...
# 18  POLYGON ((373499.122 407460.589, 373515.806 40...
# 19  MULTIPOLYGON (((385432.136 401765.792, 385427....
# 20  POLYGON ((375499.146 387479.609, 375488.606 38...
# 21  POLYGON ((387302.261 399153.162, 387313.648 39...
# 22  POLYGON ((393510.395 398453.363, 393516.529 39...
# 23  MULTIPOLYGON (((361087.118 403657.732, 361063....
# 24  POLYGON ((387796.477 401351.484, 387804.821 40...
# 25  POLYGON ((389862.161 402504.014, 389861.378 40...
# 26  POLYGON ((377442.626 387951.459, 377452.602 38...
# 27  POLYGON ((363365.066 411787.346, 363343.25 411...
# 28  POLYGON ((380644.447 410264.652, 380637.595 41...
# 29  POLYGON ((389110.896 398002.202, 389110.624 39...
# 30  POLYGON ((388578.447 400697.631, 388553.225 40...
# 31  POLYGON ((370541.84 411382.612, 370568.446 411...
# 32  POLYGON ((394177.89 408243.847, 394171.478 408...
# 33  POLYGON ((395647.133 399560.211, 395634.683 39...
# 34  POLYGON ((386802.469 402885.453, 386836.978 40...
# 35  POLYGON ((374420.151 406612.698, 374420.151 40...
# 36  POLYGON ((379130.002 416389.149, 379129.854 41...
# 37  POLYGON ((379352.807 397387.947, 379350.302 39...
# 38  POLYGON ((386253.397 404708.603, 386253.317 40...
# 39  MULTIPOLYGON (((378159.227 407469.529, 378161....
# 40  POLYGON ((380855.74 400908, 380833.049 400952....
# 41  POLYGON ((378984.749 406094.496, 378984.601 40...
# 42  MULTIPOLYGON (((392837.76 408744.463, 392838.3...
# 43  MULTIPOLYGON (((383796.323 403133.857, 383811....
# 44  POLYGON ((388609.605 402302.351, 388608.871 40...
#
#                          centroid   ref  \
# 0   POINT (355707.163 410520.464)  4362
# 1   POINT (360000.375 406294.412)  4376
# 2   POINT (364488.113 400600.946)  4381
# 3    POINT (372190.425 407595.22)  4400
# 4   POINT (378744.817 407815.339)  4408
# 5    POINT (376333.494 398534.86)  4423
# 6   POINT (377636.164 399700.487)  4424
# 7   POINT (380794.224 396941.683)  4425
# 8   POINT (373993.954 404068.892)  4427
# 9   POINT (388277.776 399437.268)  4437
# 10  POINT (398909.816 403978.854)  4443
# 11  POINT (378395.946 385314.884)  4465
# 12  POINT (380756.383 396836.056)  4468
# 13   POINT (398129.29 402832.215)  4490
# 14  POINT (394213.052 394092.183)  4496
# 15   POINT (377119.59 389446.484)  4526
# 16  POINT (388186.567 406627.903)  4546
# 17  POINT (386038.255 411640.494)  4563
# 18  POINT (373304.022 407437.941)  4580
# 19  POINT (385443.515 401656.633)  4616
# 20  POINT (375508.306 387523.737)  4622
# 21  POINT (387423.683 399200.371)  4629
# 22  POINT (391415.533 397781.433)  4674
# 23  POINT (360368.918 404017.052)  4684
# 24  POINT (387839.439 401723.582)  4685
# 25  POINT (389213.816 403660.323)  4693
# 26  POINT (377586.755 387945.708)  4702
# 27  POINT (363265.607 411676.727)  4708
# 28  POINT (380530.067 410304.034)  4716
# 29  POINT (387018.446 398443.835)  4722
# 30  POINT (386480.007 399568.197)  4723
# 31  POINT (370504.873 411321.736)  4750
# 32  POINT (394024.986 408475.516)  4763
# 33  POINT (395650.298 399507.093)  4765
# 34  POINT (386588.923 402566.271)  4769
# 35   POINT (374208.12 406614.742)  4784
# 36  POINT (379094.671 416218.161)  4790
# 37  POINT (379212.416 397407.091)  4801
# 38  POINT (385900.085 404992.843)  4813
# 39  POINT (377990.814 407585.338)  4822
# 40  POINT (381802.932 400428.987)  4831
# 41  POINT (378967.355 406195.683)  4837
# 42  POINT (392918.186 408754.106)  4842
# 43  POINT (383930.406 403005.688)  4852
# 44  POINT (388383.182 401754.226)  4858
#
#                                       Local Authority  \
# 0   POLYGON ((358668.063 410971.684, 361851.801 40...
# 1   POLYGON ((358668.063 410971.684, 361851.801 40...
# 2   POLYGON ((358668.063 410971.684, 361851.801 40...
# 3   POLYGON ((375025.76 414990.104, 374998.996 413...
# 4   POLYGON ((382118.504 413135.864, 383878.498 41...
# 5   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 6   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 7   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 8   POLYGON ((377681.197 404158.1, 379515.5 403434...
# 9   POLYGON ((384375.197 404714.801, 385603.299 40...
# 10  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 11  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 12  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 13  POLYGON ((402525.503 401459.003, 400905.596 39...
# 14  POLYGON ((402525.503 401459.003, 400905.596 39...
# 15  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 16  POLYGON ((398323.804 414179.902, 397726.598 41...
# 17  POLYGON ((398323.804 414179.902, 397726.598 41...
# 18  POLYGON ((375025.76 414990.104, 374998.996 413...
# 19  POLYGON ((384375.197 404714.801, 385603.299 40...
# 20  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 21  POLYGON ((384375.197 404714.801, 385603.299 40...
# 22  POLYGON ((402525.503 401459.003, 400905.596 39...
# 23  POLYGON ((358668.063 410971.684, 361851.801 40...
# 24  POLYGON ((384375.197 404714.801, 385603.299 40...
# 25  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 26  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 27  POLYGON ((375025.76 414990.104, 374998.996 413...
# 28  POLYGON ((382118.504 413135.864, 383878.498 41...
# 29  POLYGON ((384375.197 404714.801, 385603.299 40...
# 30  POLYGON ((384375.197 404714.801, 385603.299 40...
# 31  POLYGON ((375025.76 414990.104, 374998.996 413...
# 32  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 33  POLYGON ((402525.503 401459.003, 400905.596 39...
# 34  POLYGON ((384375.197 404714.801, 385603.299 40...
# 35  POLYGON ((375025.76 414990.104, 374998.996 413...
# 36  POLYGON ((382118.504 413135.864, 383878.498 41...
# 37  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 38  POLYGON ((384375.197 404714.801, 385603.299 40...
# 39  POLYGON ((382118.504 413135.864, 383878.498 41...
# 40  POLYGON ((377681.197 404158.1, 379515.5 403434...
# 41  POLYGON ((382118.504 413135.864, 383878.498 41...
# 42  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 43  POLYGON ((384375.197 404714.801, 385603.299 40...
# 44  POLYGON ((384375.197 404714.801, 385603.299 40...
#
#                                             SiteRef_y  No. Sites in 1km  \
# 0                              Ponds at Primrose Lane                15
# 1                           Meadow near Kirkless Hall                15
# 2                                           Firs Park                16
# 3                                  Bradford Reservoir                19
# 4                              Wetland near Radcliffe                37
# 5                                   Bridgewater Canal                21
# 6                                       Three Sisters                15
# 7                               Salford Quays (North)                33
# 8                                Blackleach Reservoir                15
# 9                                        Clayton Vale                24
# 10                                             Dacres                15
# 11                           Bentley & Tomfield Banks                21
# 12                              Salford Quays (South)                38
# 13                                   Puddle Clay Pits                21
# 14                                     Gower Hey Wood                16
# 15                          Wetland Near Balfour Road                20
# 16                                Scowcroft Reservoir                23
# 17                                  Queen's Park Lake                17
# 18              Smith Road Reservoirs & Raikes Clough                15
# 19                            Reservoirs at Harpurhey                25
# 20                                   Devisdale Meadow                16
# 21                                 Bank Bridge Meadow                16
# 22                                Ashton Canal (East)                15
# 23                                  Amberswood Common                16
# 24                                  Broadhurst Clough                24
# 25  Rochdale Canal - Lock at Scowcroft Farm to Sto...                15
# 26                                 King George V Pool                29
# 27                                       Crown Clough                17
# 28                                           Townside                37
# 29                                Ashton Canal (West)                19
# 30  Rochdale Canal - Stott's Lane to Ducie Street ...                20
# 31                                        Temple Road                30
# 32                                          Shaw Side                20
# 33                                 Stamford Park Lake                18
# 34                                Boggart Hole Clough                19
# 35                                         Moses Gate                18
# 36                                     Crow Lumb Wood                17
# 37                              Trafford Ecology Park                20
# 38                                     Boardman Brook                18
# 39             Manchester, Bolton & Bury Canal (East)                31
# 40                                       River Irwell                18
# 41                          Reservoirs at Chapelfield                16
# 42                            Ponds at Cowlishaw Farm                17
# 43                              Bowker Vale Reservoir                18
# 44                                     Moston Fairway                24
#
#     Total Sites in 1km (LA)
# 0                        62
# 1                        62
# 2                        62
# 3                        99
# 4                       138
# 5                       102
# 6                       102
# 7                       102
# 8                       102
# 9                       207
# 10                       67
# 11                      144
# 12                      144
# 13                       70
# 14                       70
# 15                      144
# 16                       40
# 17                       40
# 18                       99
# 19                      207
# 20                      144
# 21                      207
# 22                       70
# 23                       62
# 24                      207
# 25                       67
# 26                      144
# 27                       99
# 28                      138
# 29                      207
# 30                      207
# 31                       99
# 32                       67
# 33                       70
# 34                      207
# 35                       99
# 36                      138
# 37                      144
# 38                      207
# 39                      138
# 40                      102
# 41                      138
# 42                       67
# 43                      207
# 44                      207

# %%
joined_two_At_Risk = joined_two_At_Risk.drop(["Category", "SiteRef_x","SBI_Location","centroid","ref","SiteRef_y","No. Sites in 1km"], axis=1)

# %%
joined_two_At_Risk
# Out:
#         LAName                                    Local Authority  \
# 0        Wigan  POLYGON ((358668.063 410971.684, 361851.801 40...
# 1        Wigan  POLYGON ((358668.063 410971.684, 361851.801 40...
# 2        Wigan  POLYGON ((358668.063 410971.684, 361851.801 40...
# 3       Bolton  POLYGON ((375025.76 414990.104, 374998.996 413...
# 4         Bury  POLYGON ((382118.504 413135.864, 383878.498 41...
# 5      Salford  POLYGON ((377681.197 404158.1, 379515.5 403434...
# 6      Salford  POLYGON ((377681.197 404158.1, 379515.5 403434...
# 7      Salford  POLYGON ((377681.197 404158.1, 379515.5 403434...
# 8      Salford  POLYGON ((377681.197 404158.1, 379515.5 403434...
# 9   Manchester  POLYGON ((384375.197 404714.801, 385603.299 40...
# 10      Oldham  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 11    Trafford  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 12    Trafford  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 13    Tameside  POLYGON ((402525.503 401459.003, 400905.596 39...
# 14    Tameside  POLYGON ((402525.503 401459.003, 400905.596 39...
# 15    Trafford  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 16    Rochdale  POLYGON ((398323.804 414179.902, 397726.598 41...
# 17    Rochdale  POLYGON ((398323.804 414179.902, 397726.598 41...
# 18      Bolton  POLYGON ((375025.76 414990.104, 374998.996 413...
# 19  Manchester  POLYGON ((384375.197 404714.801, 385603.299 40...
# 20    Trafford  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 21  Manchester  POLYGON ((384375.197 404714.801, 385603.299 40...
# 22    Tameside  POLYGON ((402525.503 401459.003, 400905.596 39...
# 23       Wigan  POLYGON ((358668.063 410971.684, 361851.801 40...
# 24  Manchester  POLYGON ((384375.197 404714.801, 385603.299 40...
# 25      Oldham  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 26    Trafford  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 27      Bolton  POLYGON ((375025.76 414990.104, 374998.996 413...
# 28        Bury  POLYGON ((382118.504 413135.864, 383878.498 41...
# 29  Manchester  POLYGON ((384375.197 404714.801, 385603.299 40...
# 30  Manchester  POLYGON ((384375.197 404714.801, 385603.299 40...
# 31      Bolton  POLYGON ((375025.76 414990.104, 374998.996 413...
# 32      Oldham  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 33    Tameside  POLYGON ((402525.503 401459.003, 400905.596 39...
# 34  Manchester  POLYGON ((384375.197 404714.801, 385603.299 40...
# 35      Bolton  POLYGON ((375025.76 414990.104, 374998.996 413...
# 36        Bury  POLYGON ((382118.504 413135.864, 383878.498 41...
# 37    Trafford  POLYGON ((382486.204 397363.895, 383253.3 3959...
# 38  Manchester  POLYGON ((384375.197 404714.801, 385603.299 40...
# 39        Bury  POLYGON ((382118.504 413135.864, 383878.498 41...
# 40     Salford  POLYGON ((377681.197 404158.1, 379515.5 403434...
# 41        Bury  POLYGON ((382118.504 413135.864, 383878.498 41...
# 42      Oldham  POLYGON ((399470.898 413357.697, 403891.1 4072...
# 43  Manchester  POLYGON ((384375.197 404714.801, 385603.299 40...
# 44  Manchester  POLYGON ((384375.197 404714.801, 385603.299 40...
#
#     Total Sites in 1km (LA)
# 0                        62
# 1                        62
# 2                        62
# 3                        99
# 4                       138
# 5                       102
# 6                       102
# 7                       102
# 8                       102
# 9                       207
# 10                       67
# 11                      144
# 12                      144
# 13                       70
# 14                       70
# 15                      144
# 16                       40
# 17                       40
# 18                       99
# 19                      207
# 20                      144
# 21                      207
# 22                       70
# 23                       62
# 24                      207
# 25                       67
# 26                      144
# 27                       99
# 28                      138
# 29                      207
# 30                      207
# 31                       99
# 32                       67
# 33                       70
# 34                      207
# 35                       99
# 36                      138
# 37                      144
# 38                      207
# 39                      138
# 40                      102
# 41                      138
# 42                       67
# 43                      207
# 44                      207

# %%
joined_two_At_Risk.set_geometry("Local Authority")

joined_two_At_Risk = joined_two_At_Risk.set_geometry("Local Authority")

joined_two_At_Risk.explore("Total Sites in 1km (LA)")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fc10dcfb795892b9507e5d776550eb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fc10dcfb795892b9507e5d776550eb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fc10dcfb795892b9507e5d776550eb4 = L.map(
#                 &quot;map_0fc10dcfb795892b9507e5d776550eb4&quot;,
#                 {
#                     center: [53.51291160437019, -2.320019836988818],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0fc10dcfb795892b9507e5d776550eb4);
#
#
#
#
#
#             var tile_layer_09f814298c3c412b14c4fa10e432c150 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09f814298c3c412b14c4fa10e432c150.addTo(map_0fc10dcfb795892b9507e5d776550eb4);
#
#
#             map_0fc10dcfb795892b9507e5d776550eb4.fitBounds(
#                 [[53.340104395530076, -2.7304173651196653], [53.6857188132103, -1.9096223088579714]],
#                 {}
#             );
#
#
#         function geo_json_cf502923599ca98f51da8e81df84e910_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;#472e7c&quot;, &quot;fillColor&quot;: &quot;#472e7c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;18&quot;: case &quot;27&quot;: case &quot;31&quot;: case &quot;35&quot;:
#                     return {&quot;color&quot;: &quot;#2e6d8e&quot;, &quot;fillColor&quot;: &quot;#2e6d8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;28&quot;: case &quot;36&quot;: case &quot;39&quot;: case &quot;41&quot;:
#                     return {&quot;color&quot;: &quot;#21a585&quot;, &quot;fillColor&quot;: &quot;#21a585&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;40&quot;:
#                     return {&quot;color&quot;: &quot;#2c718e&quot;, &quot;fillColor&quot;: &quot;#2c718e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;25&quot;: case &quot;32&quot;: case &quot;42&quot;:
#                     return {&quot;color&quot;: &quot;#453882&quot;, &quot;fillColor&quot;: &quot;#453882&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;12&quot;: case &quot;15&quot;: case &quot;20&quot;: case &quot;26&quot;: case &quot;37&quot;:
#                     return {&quot;color&quot;: &quot;#27ad81&quot;, &quot;fillColor&quot;: &quot;#27ad81&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;14&quot;: case &quot;22&quot;: case &quot;33&quot;:
#                     return {&quot;color&quot;: &quot;#433d84&quot;, &quot;fillColor&quot;: &quot;#433d84&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_cf502923599ca98f51da8e81df84e910_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_cf502923599ca98f51da8e81df84e910_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,

# %%
joined_two_At_Risk.explore(
    column="Total Sites in 1km (LA)",
    cmap="YlGnBu",                  # change to any of the above
    tiles="CartoDB positron",
    legend=True
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92116561fbf7b3e8d791301f4ce02dee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92116561fbf7b3e8d791301f4ce02dee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92116561fbf7b3e8d791301f4ce02dee = L.map(
#                 &quot;map_92116561fbf7b3e8d791301f4ce02dee&quot;,
#                 {
#                     center: [53.51291160437019, -2.320019836988818],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_92116561fbf7b3e8d791301f4ce02dee);
#
#
#
#
#
#             var tile_layer_0a592b7c7399d58e3b01ecb49f0a7ad1 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a592b7c7399d58e3b01ecb49f0a7ad1.addTo(map_92116561fbf7b3e8d791301f4ce02dee);
#
#
#             map_92116561fbf7b3e8d791301f4ce02dee.fitBounds(
#                 [[53.340104395530076, -2.7304173651196653], [53.6857188132103, -1.9096223088579714]],
#                 {}
#             );
#
#
#         function geo_json_ff1d96889c558d893d0a3e3a2c774958_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;#ecf7b1&quot;, &quot;fillColor&quot;: &quot;#ecf7b1&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;18&quot;: case &quot;27&quot;: case &quot;31&quot;: case &quot;35&quot;:
#                     return {&quot;color&quot;: &quot;#8cd2ba&quot;, &quot;fillColor&quot;: &quot;#8cd2ba&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;28&quot;: case &quot;36&quot;: case &quot;39&quot;: case &quot;41&quot;:
#                     return {&quot;color&quot;: &quot;#289cc1&quot;, &quot;fillColor&quot;: &quot;#289cc1&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;40&quot;:
#                     return {&quot;color&quot;: &quot;#80cebb&quot;, &quot;fillColor&quot;: &quot;#80cebb&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;25&quot;: case &quot;32&quot;: case &quot;42&quot;:
#                     return {&quot;color&quot;: &quot;#e2f4b2&quot;, &quot;fillColor&quot;: &quot;#e2f4b2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;12&quot;: case &quot;15&quot;: case &quot;20&quot;: case &quot;26&quot;: case &quot;37&quot;:
#                     return {&quot;color&quot;: &quot;#1d91c0&quot;, &quot;fillColor&quot;: &quot;#1d91c0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;14&quot;: case &quot;22&quot;: case &quot;33&quot;:
#                     return {&quot;color&quot;: &quot;#ddf2b2&quot;, &quot;fillColor&quot;: &quot;#ddf2b2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#ffffd9&quot;, &quot;fillColor&quot;: &quot;#ffffd9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#081d58&quot;, &quot;fillColor&quot;: &quot;#081d58&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ff1d96889c558d893d0a3e3a2c774958_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ff1d96889c558d893d0a3e3a2c774958_pointToLayer(featur

# %%
joined_two_At_Risk.explore(
    column="Total Sites in 1km (LA)",
    cmap="RdYlGn_r",  # green (low) to red (high)
    tiles="CartoDB positron",
    legend=True,
    legend_kwds={'caption': 'Sites at Risk (within 1km)'}
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d15cc8b6e960f9009d6c997a5754d1b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d15cc8b6e960f9009d6c997a5754d1b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d15cc8b6e960f9009d6c997a5754d1b1 = L.map(
#                 &quot;map_d15cc8b6e960f9009d6c997a5754d1b1&quot;,
#                 {
#                     center: [53.51291160437019, -2.320019836988818],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d15cc8b6e960f9009d6c997a5754d1b1);
#
#
#
#
#
#             var tile_layer_6b2584ac944aa11ff4cc5e3a07183abf = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b2584ac944aa11ff4cc5e3a07183abf.addTo(map_d15cc8b6e960f9009d6c997a5754d1b1);
#
#
#             map_d15cc8b6e960f9009d6c997a5754d1b1.fitBounds(
#                 [[53.340104395530076, -2.7304173651196653], [53.6857188132103, -1.9096223088579714]],
#                 {}
#             );
#
#
#         function geo_json_8e010bad66fd8ce71abad0fd7f476101_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;#30a356&quot;, &quot;fillColor&quot;: &quot;#30a356&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;18&quot;: case &quot;27&quot;: case &quot;31&quot;: case &quot;35&quot;:
#                     return {&quot;color&quot;: &quot;#c1e57b&quot;, &quot;fillColor&quot;: &quot;#c1e57b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;28&quot;: case &quot;36&quot;: case &quot;39&quot;: case &quot;41&quot;:
#                     return {&quot;color&quot;: &quot;#fee491&quot;, &quot;fillColor&quot;: &quot;#fee491&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;40&quot;:
#                     return {&quot;color&quot;: &quot;#cbe982&quot;, &quot;fillColor&quot;: &quot;#cbe982&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;25&quot;: case &quot;32&quot;: case &quot;42&quot;:
#                     return {&quot;color&quot;: &quot;#48ae5c&quot;, &quot;fillColor&quot;: &quot;#48ae5c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;12&quot;: case &quot;15&quot;: case &quot;20&quot;: case &quot;26&quot;: case &quot;37&quot;:
#                     return {&quot;color&quot;: &quot;#fed481&quot;, &quot;fillColor&quot;: &quot;#fed481&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;14&quot;: case &quot;22&quot;: case &quot;33&quot;:
#                     return {&quot;color&quot;: &quot;#54b45f&quot;, &quot;fillColor&quot;: &quot;#54b45f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#006837&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#a50026&quot;, &quot;fillColor&quot;: &quot;#a50026&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8e010bad66fd8ce71abad0fd7f476101_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8e010bad66fd8ce71abad0fd7f476101_pointToLayer(featur
