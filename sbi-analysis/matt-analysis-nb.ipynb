# %% [markdown]
# # Matt's analysis

# %%
# Write some code here

print("Hello")
# Out:
# Hello

# %%
import geopandas as gpd

boundaries = gpd.read_file("data/boundaries/LAD_DEC_24_UK_BUC.shp")

boundaries.head(10)
# Out:
#      LAD24CD                      LAD24NM LAD24NMW   BNG_E   BNG_N     LONG  \
# 0  E06000001                   Hartlepool     None  447161  531473 -1.27017
# 1  E06000002                Middlesbrough     None  451141  516887 -1.21100
# 2  E06000003         Redcar and Cleveland     None  464330  519596 -1.00657
# 3  E06000004             Stockton-on-Tees     None  444940  518179 -1.30665
# 4  E06000005                   Darlington     None  428029  515648 -1.56836
# 5  E06000006                       Halton     None  354246  382146 -2.68854
# 6  E06000007                   Warrington     None  362744  388457 -2.56168
# 7  E06000008        Blackburn with Darwen     None  369489  422806 -2.46362
# 8  E06000009                    Blackpool     None  332817  436635 -3.02203
# 9  E06000010  Kingston upon Hull, City of     None  511892  431651 -0.30386
#
#        LAT                              GlobalID  \
# 0  54.6761  c28e4b7c-841f-4db2-91d8-2ab1cef4bd23
# 1  54.5447  b897a799-65cd-413a-a79c-521fd2986aa5
# 2  54.5675  05c2cef1-c39b-4250-acc8-a2eab00a5f0f
# 3  54.5569  ee992892-bd1a-4478-aa48-8774a14f0e61
# 4  54.5353  e023797a-6a3f-4819-93e2-cff964746280
# 5  53.3343  0989e288-8361-4152-8bf5-8073cd8128c8
# 6  53.3916  0ff3f07b-af94-480c-9891-d150b8d7c216
# 7  53.7008  7fed668d-1d94-4efd-be81-d80d6dfb3e1c
# 8  53.8216  42ecea30-61c9-4269-9458-f2466193519d
# 9  53.7692  0c186cbf-ae15-4afa-922a-1d67637233ce
#
#                                             geometry
# 0  POLYGON ((448964.105 536757.184, 448986.025 53...
# 1  POLYGON ((451894.299 521145.303, 453997.697 51...
# 2  POLYGON ((478232.947 518788.803, 477689.303 51...
# 3  POLYGON ((452243.536 526335.188, 451711.3 5256...
# 4  POLYGON ((436388.002 522354.197, 437351.702 52...
# 5  MULTIPOLYGON (((358131.901 385425.802, 358057....
# 6  POLYGON ((367582.201 396058.199, 370229.203 39...
# 7  POLYGON ((372965.929 423270.852, 373792.496 42...
# 8  POLYGON ((333572.799 437130.702, 334590.801 43...
# 9  POLYGON ((515453.213 427773.127, 513098.15 428...

# %%
boundaries.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_353214e16cd1d47a189161220fbbc36d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_353214e16cd1d47a189161220fbbc36d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_353214e16cd1d47a189161220fbbc36d = L.map(
#                 &quot;map_353214e16cd1d47a189161220fbbc36d&quot;,
#                 {
#                     center: [55.371596079476426, -3.443163547638964],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_353214e16cd1d47a189161220fbbc36d);
#
#
#
#
#
#             var tile_layer_9bef73256ddb2a06d4a486abb72187bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9bef73256ddb2a06d4a486abb72187bb.addTo(map_353214e16cd1d47a189161220fbbc36d);
#
#
#             map_353214e16cd1d47a189161220fbbc36d.fitBounds(
#                 [[49.882346322739934, -8.650007201985835], [60.86084583621292, 1.7636801067079062]],
#                 {}
#             );
#
#
#         function geo_json_d72b12ffc2c267ebc943309a09aab1a0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d72b12ffc2c267ebc943309a09aab1a0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d72b12ffc2c267ebc943309a09aab1a0_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_d72b12ffc2c267ebc943309a09aab1a0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d72b12ffc2c267ebc943309a09aab1a0_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_d72b12ffc2c267ebc943309a09aab1a0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d72b12ffc2c267ebc943309a09aab1a0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d72b12ffc2c267ebc943309a09aab1a0 = L.geoJson(null, {
#                 onEachFeature: geo_json_d72b12ffc2c267ebc943309a09aab1a0_onEachFeature,
#
#                 style: geo_json_d72b12ffc2c267ebc943309a09aab1a0_styler,
#                 pointToLayer: geo_json_d72b12ffc2c267ebc943309a09aab1a0_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_d72b12ffc2c267ebc943309a09aab1a0_add (data) {
#             geo_json_d72b12ffc2c267ebc943309a09aab1a0
#                 .addData(data);
#         }
#             geo_json_d72b12ffc2c267ebc943309a09aab1a0_add({&quot;bbox&quot;: [-8.650007201985835, 49.882346322739934, 1.7636801067079062, 60.86084583621292], &quot;features&quot;: [{&quot;bbox&quot;: [-1.3808335752789866, 54.62167312076519, -1.157622586837751, 54.72715842085315], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.2413155203250532, 54.72343281478615], [-1.240979843007309, 54.72318348692134], [-1.1761545519170093, 54.69767558427452], [-1.173999750244433, 54.69186456604039]
