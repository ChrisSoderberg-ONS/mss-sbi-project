# %% [markdown]
# # Example notebook
#
# This is page exists to show you how to add additional notebooks to the book. Notebooks are used to display functional code, outputs and text together in the same document.

# %% [markdown]
# ## Example code - Calculating distances between centroids
#
# Load and join up the example data:

# %%
import geopandas as gpd
import pandas as pd

# Load and join GMCA housing, industrial and office supply data

housing_supply_gdf = gpd.read_file("data/gmca_data/2024 GM Housing Land Supply GIS.shp")
industrial_supply_gdf = gpd.read_file("data/gmca_data/2024 GM Industrial-warehousing Land Supply GIS.shp")
offices_supply_gdf = gpd.read_file("data/gmca_data/2024 GM Offices Land Supply GIS.shp")

total_supply_gdf = pd.concat(
    [housing_supply_gdf, industrial_supply_gdf, offices_supply_gdf]
)

# Load and tidy GMEU Sites of Biological Importance data

sbi_gdf = gpd.read_file("data/gmeu_data/gm_sbi.shp")

sbi_gdf["Category"] = "Site of Biological Importance"

sbi_gdf = sbi_gdf.rename(columns = {"district": "LAName", "site_nam": "SiteRef"})

# Join GMCA and GMEU data

full_data_gdf = pd.concat(
    [total_supply_gdf, sbi_gdf[["SiteRef", "LAName", "Category", "geometry"]]]
)

# %% [markdown]
# We can use GeoPandas to get the centroids of all our data:

# %%
full_data_gdf["centroid"] = full_data_gdf.centroid

# %% [markdown]
# Now we can extract the location of a random SBI and a random proposed development site:

# %%
random_sbi = full_data_gdf[
    full_data_gdf["Category"] == "Site of Biological Importance"
    ].sample(1)

random_sbi = random_sbi["centroid"].iloc[0]

print(random_sbi)
# Out:
# POINT (354476.5765390646 406701.8024530355)

# %%
random_housing = full_data_gdf[
    full_data_gdf["Category"] == "Housing"
    ].sample(1)

random_housing = random_housing["centroid"].iloc[0]

print(random_housing)
# Out:
# POINT (384677.49539871 391085.9918037708)

# %% [markdown]
# The distance between two Point objects can be calculated using Shapely:

# %%
import shapely

print(
    round(shapely.distance(random_housing, random_sbi), 2)
)
# Out:
# 33999.25

# %%
full_data_gdf.sample(10)
# Out:
#                            Category      LAName                      SiteRef  \
# 262          Industrial/warehousing    Tameside                 E-STPETE-020
# 3340                        Housing       Wigan                         0449
# 2165                        Housing   Stockport                      STO2180
# 3019                        Housing       Wigan                         0003
# 3533                        Housing      Bolton                      HLA-466
# 1877                        Housing     Salford                    H/ECC/037
# 3720                        Housing      Bolton                      HLA-605
# 284                         Housing  Manchester                 Char_Cap_004
# 114                         Offices  Manchester                   MCC_EMP_12
# 411   Site of Biological Importance     Salford  Marsh near Clifton Junction
#
#                                                geometry  \
# 262   POLYGON ((392966.2 399064.8, 392969.329 399066...
# 3340  MULTIPOLYGON (((363258.796 396996.472, 363259....
# 2165  POLYGON ((389946.695 392557.742, 389946.048 39...
# 3019  POLYGON ((368841.45 403637.6, 368853.168 40363...
# 3533  POLYGON ((366587.63 407361.09, 366608.43 40735...
# 1877  POLYGON ((377963.35 399409.55, 377964.501 3994...
# 3720  POLYGON ((372241.5 413301.6, 372242.1 413302.2...
# 284   POLYGON ((387423.781 402435.295, 387415.485 40...
# 114   POLYGON Z ((381463.398 385992.725 0, 381514.58...
# 411   POLYGON ((379324.829 402514.517, 379334.22 402...
#
#                            centroid
# 262   POINT (392977.841 399009.319)
# 3340   POINT (363505.766 397174.55)
# 2165   POINT (389949.82 392578.167)
# 3019  POINT (368629.886 403172.997)
# 3533  POINT (366620.332 407354.401)
# 1877  POINT (377955.864 399384.038)
# 3720  POINT (372247.452 413303.281)
# 284   POINT (387526.671 402527.393)
# 114   POINT (381973.592 385847.605)
# 411    POINT (379236.44 402484.752)

# %%
import geopandas as gpd

boundaries = gpd.read_file("data/boundaries/LAD_DEC_24_UK_BUC.shp")

pd.merge(full_data_gdf, boundaries, left_on = "LAName", right_on = "LAD24NM", how = "left")
# Out:
#                            Category      LAName  \
# 0                           Housing        Bury
# 1                           Housing        Bury
# 2                           Housing        Bury
# 3                           Housing        Bury
# 4                           Housing        Bury
# ...                             ...         ...
# 4888  Site of Biological Importance    Tameside
# 4889  Site of Biological Importance       Wigan
# 4890  Site of Biological Importance  Manchester
# 4891  Site of Biological Importance  Manchester
# 4892  Site of Biological Importance      Bolton
#
#                                    SiteRef  \
# 0                               HL/0414/00
# 1                               HL/1172/00
# 2                               HL/1981/00
# 3                               HL/2004/00
# 4                               HL/2127/00
# ...                                    ...
# 4888  Mill Race & Pasture at Haughton Dale
# 4889                         Three Sisters
# 4890                         Nan Nook Wood
# 4891                              Big Wood
# 4892                     Bank Wood & Marsh
#
#                                              geometry_x  \
# 0     POLYGON ((379112.8 410310.51, 379117.56 410306...
# 1     POLYGON ((377973.95 414475.81, 377979.24 41446...
# 2     POLYGON ((380839 413359.78, 380838.6 413361.95...
# 3     POLYGON ((378834 407567.1, 378840 407566.81, 3...
# 4     POLYGON ((379113.7 410329.59, 379114.66 410328...
# ...                                                 ...
# 4888  MULTIPOLYGON (((393687.128 393384.895, 393682....
# 4889  POLYGON ((357928.939 401185.293, 357957.618 40...
# 4890  POLYGON ((381158.403 390125.048, 381156.853 39...
# 4891  MULTIPOLYGON (((383512.797 386267.952, 383512....
# 4892  POLYGON ((369344.075 408685.587, 369329.313 40...
#
#                            centroid    LAD24CD     LAD24NM LAD24NMW   BNG_E  \
# 0     POINT (379114.012 410213.116)  E08000002        Bury     None  379658
# 1     POINT (377947.835 414384.462)  E08000002        Bury     None  379658
# 2     POINT (380885.718 413390.494)  E08000002        Bury     None  379658
# 3       POINT (378852.408 407559.6)  E08000002        Bury     None  379658
# 4       POINT (379117.39 410313.26)  E08000002        Bury     None  379658
# ...                             ...        ...         ...      ...     ...
# 4888  POINT (393841.341 393512.227)  E08000008    Tameside     None  394987
# 4889  POINT (358367.769 401012.636)  E08000010       Wigan     None  362139
# 4890  POINT (380888.856 390037.976)  E08000003  Manchester     None  384591
# 4891  POINT (383309.435 386406.658)  E08000003  Manchester     None  384591
# 4892  POINT (368971.201 408737.581)  E08000001      Bolton     None  368352
#
#        BNG_N     LONG      LAT                              GlobalID  \
# 0     410767 -2.30880  53.5931  9b925fe0-4d83-431f-83c3-434ba20a3183
# 1     410767 -2.30880  53.5931  9b925fe0-4d83-431f-83c3-434ba20a3183
# 2     410767 -2.30880  53.5931  9b925fe0-4d83-431f-83c3-434ba20a3183
# 3     410767 -2.30880  53.5931  9b925fe0-4d83-431f-83c3-434ba20a3183
# 4     410767 -2.30880  53.5931  9b925fe0-4d83-431f-83c3-434ba20a3183
# ...      ...      ...      ...                                   ...
# 4888  397995 -2.07700  53.4787  d32aeedd-2000-4d80-b729-7484ebf85e64
# 4889  402126 -2.57242  53.5145  80163100-345f-4a19-9eae-09f2bda28a68
# 4890  397063 -2.23360  53.4701  6a898ce9-19ca-4131-bdb4-6d5d85051598
# 4891  397063 -2.23360  53.4701  6a898ce9-19ca-4131-bdb4-6d5d85051598
# 4892  409874 -2.47952  53.5845  1a6dece7-30d2-4c72-9e0b-ecf22b13ae70
#
#                                              geometry_y
# 0     POLYGON ((382118.504 413135.864, 383878.498 41...
# 1     POLYGON ((382118.504 413135.864, 383878.498 41...
# 2     POLYGON ((382118.504 413135.864, 383878.498 41...
# 3     POLYGON ((382118.504 413135.864, 383878.498 41...
# 4     POLYGON ((382118.504 413135.864, 383878.498 41...
# ...                                                 ...
# 4888  POLYGON ((402525.503 401459.003, 400905.596 39...
# 4889  POLYGON ((358668.063 410971.684, 361851.801 40...
# 4890  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4891  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4892  POLYGON ((375025.76 414990.104, 374998.996 413...
#
# [4893 rows x 14 columns]

# %%
joined_one = pd.merge(full_data_gdf, boundaries, left_on = "LAName", right_on = "LAD24NM", how = "left")

# %%
joined_one
# Out:
#                            Category      LAName  \
# 0                           Housing        Bury
# 1                           Housing        Bury
# 2                           Housing        Bury
# 3                           Housing        Bury
# 4                           Housing        Bury
# ...                             ...         ...
# 4888  Site of Biological Importance    Tameside
# 4889  Site of Biological Importance       Wigan
# 4890  Site of Biological Importance  Manchester
# 4891  Site of Biological Importance  Manchester
# 4892  Site of Biological Importance      Bolton
#
#                                    SiteRef  \
# 0                               HL/0414/00
# 1                               HL/1172/00
# 2                               HL/1981/00
# 3                               HL/2004/00
# 4                               HL/2127/00
# ...                                    ...
# 4888  Mill Race & Pasture at Haughton Dale
# 4889                         Three Sisters
# 4890                         Nan Nook Wood
# 4891                              Big Wood
# 4892                     Bank Wood & Marsh
#
#                                              geometry_x  \
# 0     POLYGON ((379112.8 410310.51, 379117.56 410306...
# 1     POLYGON ((377973.95 414475.81, 377979.24 41446...
# 2     POLYGON ((380839 413359.78, 380838.6 413361.95...
# 3     POLYGON ((378834 407567.1, 378840 407566.81, 3...
# 4     POLYGON ((379113.7 410329.59, 379114.66 410328...
# ...                                                 ...
# 4888  MULTIPOLYGON (((393687.128 393384.895, 393682....
# 4889  POLYGON ((357928.939 401185.293, 357957.618 40...
# 4890  POLYGON ((381158.403 390125.048, 381156.853 39...
# 4891  MULTIPOLYGON (((383512.797 386267.952, 383512....
# 4892  POLYGON ((369344.075 408685.587, 369329.313 40...
#
#                            centroid    LAD24CD     LAD24NM LAD24NMW   BNG_E  \
# 0     POINT (379114.012 410213.116)  E08000002        Bury     None  379658
# 1     POINT (377947.835 414384.462)  E08000002        Bury     None  379658
# 2     POINT (380885.718 413390.494)  E08000002        Bury     None  379658
# 3       POINT (378852.408 407559.6)  E08000002        Bury     None  379658
# 4       POINT (379117.39 410313.26)  E08000002        Bury     None  379658
# ...                             ...        ...         ...      ...     ...
# 4888  POINT (393841.341 393512.227)  E08000008    Tameside     None  394987
# 4889  POINT (358367.769 401012.636)  E08000010       Wigan     None  362139
# 4890  POINT (380888.856 390037.976)  E08000003  Manchester     None  384591
# 4891  POINT (383309.435 386406.658)  E08000003  Manchester     None  384591
# 4892  POINT (368971.201 408737.581)  E08000001      Bolton     None  368352
#
#        BNG_N     LONG      LAT                              GlobalID  \
# 0     410767 -2.30880  53.5931  9b925fe0-4d83-431f-83c3-434ba20a3183
# 1     410767 -2.30880  53.5931  9b925fe0-4d83-431f-83c3-434ba20a3183
# 2     410767 -2.30880  53.5931  9b925fe0-4d83-431f-83c3-434ba20a3183
# 3     410767 -2.30880  53.5931  9b925fe0-4d83-431f-83c3-434ba20a3183
# 4     410767 -2.30880  53.5931  9b925fe0-4d83-431f-83c3-434ba20a3183
# ...      ...      ...      ...                                   ...
# 4888  397995 -2.07700  53.4787  d32aeedd-2000-4d80-b729-7484ebf85e64
# 4889  402126 -2.57242  53.5145  80163100-345f-4a19-9eae-09f2bda28a68
# 4890  397063 -2.23360  53.4701  6a898ce9-19ca-4131-bdb4-6d5d85051598
# 4891  397063 -2.23360  53.4701  6a898ce9-19ca-4131-bdb4-6d5d85051598
# 4892  409874 -2.47952  53.5845  1a6dece7-30d2-4c72-9e0b-ecf22b13ae70
#
#                                              geometry_y
# 0     POLYGON ((382118.504 413135.864, 383878.498 41...
# 1     POLYGON ((382118.504 413135.864, 383878.498 41...
# 2     POLYGON ((382118.504 413135.864, 383878.498 41...
# 3     POLYGON ((382118.504 413135.864, 383878.498 41...
# 4     POLYGON ((382118.504 413135.864, 383878.498 41...
# ...                                                 ...
# 4888  POLYGON ((402525.503 401459.003, 400905.596 39...
# 4889  POLYGON ((358668.063 410971.684, 361851.801 40...
# 4890  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4891  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4892  POLYGON ((375025.76 414990.104, 374998.996 413...
#
# [4893 rows x 14 columns]

# %%
joined_one = joined_one.drop(columns=["LAD24NM","LAD24NMW","BNG_E","BNG_N","LONG","LAT","GlobalID"])

# %%
joined_one
# Out:
#                            Category      LAName  \
# 0                           Housing        Bury
# 1                           Housing        Bury
# 2                           Housing        Bury
# 3                           Housing        Bury
# 4                           Housing        Bury
# ...                             ...         ...
# 4888  Site of Biological Importance    Tameside
# 4889  Site of Biological Importance       Wigan
# 4890  Site of Biological Importance  Manchester
# 4891  Site of Biological Importance  Manchester
# 4892  Site of Biological Importance      Bolton
#
#                                    SiteRef  \
# 0                               HL/0414/00
# 1                               HL/1172/00
# 2                               HL/1981/00
# 3                               HL/2004/00
# 4                               HL/2127/00
# ...                                    ...
# 4888  Mill Race & Pasture at Haughton Dale
# 4889                         Three Sisters
# 4890                         Nan Nook Wood
# 4891                              Big Wood
# 4892                     Bank Wood & Marsh
#
#                                              geometry_x  \
# 0     POLYGON ((379112.8 410310.51, 379117.56 410306...
# 1     POLYGON ((377973.95 414475.81, 377979.24 41446...
# 2     POLYGON ((380839 413359.78, 380838.6 413361.95...
# 3     POLYGON ((378834 407567.1, 378840 407566.81, 3...
# 4     POLYGON ((379113.7 410329.59, 379114.66 410328...
# ...                                                 ...
# 4888  MULTIPOLYGON (((393687.128 393384.895, 393682....
# 4889  POLYGON ((357928.939 401185.293, 357957.618 40...
# 4890  POLYGON ((381158.403 390125.048, 381156.853 39...
# 4891  MULTIPOLYGON (((383512.797 386267.952, 383512....
# 4892  POLYGON ((369344.075 408685.587, 369329.313 40...
#
#                            centroid    LAD24CD  \
# 0     POINT (379114.012 410213.116)  E08000002
# 1     POINT (377947.835 414384.462)  E08000002
# 2     POINT (380885.718 413390.494)  E08000002
# 3       POINT (378852.408 407559.6)  E08000002
# 4       POINT (379117.39 410313.26)  E08000002
# ...                             ...        ...
# 4888  POINT (393841.341 393512.227)  E08000008
# 4889  POINT (358367.769 401012.636)  E08000010
# 4890  POINT (380888.856 390037.976)  E08000003
# 4891  POINT (383309.435 386406.658)  E08000003
# 4892  POINT (368971.201 408737.581)  E08000001
#
#                                              geometry_y
# 0     POLYGON ((382118.504 413135.864, 383878.498 41...
# 1     POLYGON ((382118.504 413135.864, 383878.498 41...
# 2     POLYGON ((382118.504 413135.864, 383878.498 41...
# 3     POLYGON ((382118.504 413135.864, 383878.498 41...
# 4     POLYGON ((382118.504 413135.864, 383878.498 41...
# ...                                                 ...
# 4888  POLYGON ((402525.503 401459.003, 400905.596 39...
# 4889  POLYGON ((358668.063 410971.684, 361851.801 40...
# 4890  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4891  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4892  POLYGON ((375025.76 414990.104, 374998.996 413...
#
# [4893 rows x 7 columns]

# %%
joined_one.rename(columns={'geometry_x': 'SBI_Location', 'geometry_y': 'Local Authority'}, inplace=True)

# %%
joined_one
# Out:
#                            Category      LAName  \
# 0                           Housing        Bury
# 1                           Housing        Bury
# 2                           Housing        Bury
# 3                           Housing        Bury
# 4                           Housing        Bury
# ...                             ...         ...
# 4888  Site of Biological Importance    Tameside
# 4889  Site of Biological Importance       Wigan
# 4890  Site of Biological Importance  Manchester
# 4891  Site of Biological Importance  Manchester
# 4892  Site of Biological Importance      Bolton
#
#                                    SiteRef  \
# 0                               HL/0414/00
# 1                               HL/1172/00
# 2                               HL/1981/00
# 3                               HL/2004/00
# 4                               HL/2127/00
# ...                                    ...
# 4888  Mill Race & Pasture at Haughton Dale
# 4889                         Three Sisters
# 4890                         Nan Nook Wood
# 4891                              Big Wood
# 4892                     Bank Wood & Marsh
#
#                                            SBI_Location  \
# 0     POLYGON ((379112.8 410310.51, 379117.56 410306...
# 1     POLYGON ((377973.95 414475.81, 377979.24 41446...
# 2     POLYGON ((380839 413359.78, 380838.6 413361.95...
# 3     POLYGON ((378834 407567.1, 378840 407566.81, 3...
# 4     POLYGON ((379113.7 410329.59, 379114.66 410328...
# ...                                                 ...
# 4888  MULTIPOLYGON (((393687.128 393384.895, 393682....
# 4889  POLYGON ((357928.939 401185.293, 357957.618 40...
# 4890  POLYGON ((381158.403 390125.048, 381156.853 39...
# 4891  MULTIPOLYGON (((383512.797 386267.952, 383512....
# 4892  POLYGON ((369344.075 408685.587, 369329.313 40...
#
#                            centroid    LAD24CD  \
# 0     POINT (379114.012 410213.116)  E08000002
# 1     POINT (377947.835 414384.462)  E08000002
# 2     POINT (380885.718 413390.494)  E08000002
# 3       POINT (378852.408 407559.6)  E08000002
# 4       POINT (379117.39 410313.26)  E08000002
# ...                             ...        ...
# 4888  POINT (393841.341 393512.227)  E08000008
# 4889  POINT (358367.769 401012.636)  E08000010
# 4890  POINT (380888.856 390037.976)  E08000003
# 4891  POINT (383309.435 386406.658)  E08000003
# 4892  POINT (368971.201 408737.581)  E08000001
#
#                                         Local Authority
# 0     POLYGON ((382118.504 413135.864, 383878.498 41...
# 1     POLYGON ((382118.504 413135.864, 383878.498 41...
# 2     POLYGON ((382118.504 413135.864, 383878.498 41...
# 3     POLYGON ((382118.504 413135.864, 383878.498 41...
# 4     POLYGON ((382118.504 413135.864, 383878.498 41...
# ...                                                 ...
# 4888  POLYGON ((402525.503 401459.003, 400905.596 39...
# 4889  POLYGON ((358668.063 410971.684, 361851.801 40...
# 4890  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4891  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4892  POLYGON ((375025.76 414990.104, 374998.996 413...
#
# [4893 rows x 7 columns]

# %%
joined_one = joined_one.drop(columns=["LAD24CD"])

# %%
joined_one
# Out:
#                            Category      LAName  \
# 0                           Housing        Bury
# 1                           Housing        Bury
# 2                           Housing        Bury
# 3                           Housing        Bury
# 4                           Housing        Bury
# ...                             ...         ...
# 4888  Site of Biological Importance    Tameside
# 4889  Site of Biological Importance       Wigan
# 4890  Site of Biological Importance  Manchester
# 4891  Site of Biological Importance  Manchester
# 4892  Site of Biological Importance      Bolton
#
#                                    SiteRef  \
# 0                               HL/0414/00
# 1                               HL/1172/00
# 2                               HL/1981/00
# 3                               HL/2004/00
# 4                               HL/2127/00
# ...                                    ...
# 4888  Mill Race & Pasture at Haughton Dale
# 4889                         Three Sisters
# 4890                         Nan Nook Wood
# 4891                              Big Wood
# 4892                     Bank Wood & Marsh
#
#                                            SBI_Location  \
# 0     POLYGON ((379112.8 410310.51, 379117.56 410306...
# 1     POLYGON ((377973.95 414475.81, 377979.24 41446...
# 2     POLYGON ((380839 413359.78, 380838.6 413361.95...
# 3     POLYGON ((378834 407567.1, 378840 407566.81, 3...
# 4     POLYGON ((379113.7 410329.59, 379114.66 410328...
# ...                                                 ...
# 4888  MULTIPOLYGON (((393687.128 393384.895, 393682....
# 4889  POLYGON ((357928.939 401185.293, 357957.618 40...
# 4890  POLYGON ((381158.403 390125.048, 381156.853 39...
# 4891  MULTIPOLYGON (((383512.797 386267.952, 383512....
# 4892  POLYGON ((369344.075 408685.587, 369329.313 40...
#
#                            centroid  \
# 0     POINT (379114.012 410213.116)
# 1     POINT (377947.835 414384.462)
# 2     POINT (380885.718 413390.494)
# 3       POINT (378852.408 407559.6)
# 4       POINT (379117.39 410313.26)
# ...                             ...
# 4888  POINT (393841.341 393512.227)
# 4889  POINT (358367.769 401012.636)
# 4890  POINT (380888.856 390037.976)
# 4891  POINT (383309.435 386406.658)
# 4892  POINT (368971.201 408737.581)
#
#                                         Local Authority
# 0     POLYGON ((382118.504 413135.864, 383878.498 41...
# 1     POLYGON ((382118.504 413135.864, 383878.498 41...
# 2     POLYGON ((382118.504 413135.864, 383878.498 41...
# 3     POLYGON ((382118.504 413135.864, 383878.498 41...
# 4     POLYGON ((382118.504 413135.864, 383878.498 41...
# ...                                                 ...
# 4888  POLYGON ((402525.503 401459.003, 400905.596 39...
# 4889  POLYGON ((358668.063 410971.684, 361851.801 40...
# 4890  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4891  POLYGON ((384375.197 404714.801, 385603.299 40...
# 4892  POLYGON ((375025.76 414990.104, 374998.996 413...
#
# [4893 rows x 6 columns]
