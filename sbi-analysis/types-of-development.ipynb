# %% [markdown]
# # Types of Development
#
# In this notebook, for the "at risk" sites, we will classify what is causing them to be the most at risk, from housing, offices, and industrial.

# %%
#First recreate the data from the preliminary analysis
import geopandas as gpd
import pandas as pd

# Load and join GMCA housing, industrial and office supply data
housing_supply_gdf = gpd.read_file("data/gmca_data/2024 GM Housing Land Supply GIS.shp")
industrial_supply_gdf = gpd.read_file("data/gmca_data/2024 GM Industrial-warehousing Land Supply GIS.shp")
offices_supply_gdf = gpd.read_file("data/gmca_data/2024 GM Offices Land Supply GIS.shp")
total_supply_gdf = pd.concat(
    [housing_supply_gdf, industrial_supply_gdf, offices_supply_gdf]
)

# Load and tidy GMEU Sites of Biological Importance data
sbi_gdf = gpd.read_file("data/gmeu_data/gm_sbi.shp")
sbi_gdf["Category"] = "Site of Biological Importance"
sbi_gdf = sbi_gdf.rename(columns = {"district": "LAName", "site_nam": "SiteRef"})

# Join GMCA and GMEU data
full_data_gdf = pd.concat(
    [total_supply_gdf, sbi_gdf[["SiteRef", "LAName", "Category", "geometry"]]]
)

#Use geopandas to get centroids of all the sites
full_data_gdf["centroid"] = full_data_gdf.centroid

#Split into sites of biological importance and non-biological importance
sbi = full_data_gdf[full_data_gdf["Category"] == "Site of Biological Importance"]
non_sbi = full_data_gdf[full_data_gdf["Category"] != "Site of Biological Importance"]

#Find the number of new developments less than 1km away for each SBI
sbinames = list(sbi["SiteRef"]) #list of all the sbis
distances = list()
less_than_1km = list() #creating empty lists to add to data frame

for x in sbi["centroid"]: #loop through each sbi
    y = non_sbi["centroid"].distance(x) #find all the distances of developments to centroid
    for distance in y: #filter for less than 1km away
            if distance <1000:
                distances.append(distance)
    r = len(distances)    #find no. developments less than 1km away to each sbi
    less_than_1km.append(r)
    distances = list()

Dev_1km = pd.DataFrame({'SiteRef':sbinames, 'No. Sites in 1km': less_than_1km}) #create dataframe of sbi and no. developments

# %%
#Choose final risk as 90% threshold, >14 and plot on the map for reference

Dev_1km = Dev_1km[Dev_1km["No. Sites in 1km"] >14]

Dev_1km = pd.merge(sbi, Dev_1km, on="SiteRef")

Dev_1km.explore( tiles="CartoDB positron")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a46bd39f5c6ef63b698fcfefcdb122e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a46bd39f5c6ef63b698fcfefcdb122e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a46bd39f5c6ef63b698fcfefcdb122e8 = L.map(
#                 &quot;map_a46bd39f5c6ef63b698fcfefcdb122e8&quot;,
#                 {
#                     center: [53.50301382478645, -2.344313027321376],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a46bd39f5c6ef63b698fcfefcdb122e8);
#
#
#
#
#
#             var tile_layer_bec87efd9a1b57409682a7318738e1f0 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bec87efd9a1b57409682a7318738e1f0.addTo(map_a46bd39f5c6ef63b698fcfefcdb122e8);
#
#
#             map_a46bd39f5c6ef63b698fcfefcdb122e8.fitBounds(
#                 [[53.362244797755025, -2.6724108559697153], [53.64378285181788, -2.016215198673037]],
#                 {}
#             );
#
#
#         function geo_json_3c056d9dddce05a2888fca00c0a85efe_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3c056d9dddce05a2888fca00c0a85efe_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3c056d9dddce05a2888fca00c0a85efe_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_3c056d9dddce05a2888fca00c0a85efe_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3c056d9dddce05a2888fca00c0a85efe_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_3c056d9dddce05a2888fca00c0a85efe.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3c056d9dddce05a2888fca00c0a85efe_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3c056d9dddce05a2888fca00c0a85efe = L.geoJson(null, {
#                 onEachFeature: geo_json_3c056d9dddce05a2888fca00c0a85efe_onEachFeature,
#
#                 style: geo_json_3c056d9dddce05a2888fca00c0a85efe_styler,
#                 pointToLayer: geo_json_3c056d9dddce05a2888fca00c0a85efe_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_3c056d9dddce05a2888fca00c0a85efe_add (data) {
#             geo_json_3c056d9dddce05a2888fca00c0a85efe
#                 .addData(data);
#         }
#             geo_json_3c056d9dddce05a2888fca00c0a85efe_add({&quot;bbox&quot;: [-2.6724108559697153, 53.362244797755025, -2.016215198673037, 53.64378285181788], &quot;features&quot;: [{&quot;bbox&quot;: [-2.6724108559697153, 53.58852727384891, -2.6686986632541467, 53.59018154495132], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-2.6724108559697153, 53.589611626130335], [-2.672083

# %%
Dev_1km
# Out:
#                          Category      LAName  \
# 0   Site of Biological Importance       Wigan
# 1   Site of Biological Importance       Wigan
# 2   Site of Biological Importance       Wigan
# 3   Site of Biological Importance      Bolton
# 4   Site of Biological Importance        Bury
# 5   Site of Biological Importance     Salford
# 6   Site of Biological Importance     Salford
# 7   Site of Biological Importance     Salford
# 8   Site of Biological Importance     Salford
# 9   Site of Biological Importance  Manchester
# 10  Site of Biological Importance      Oldham
# 11  Site of Biological Importance    Trafford
# 12  Site of Biological Importance    Trafford
# 13  Site of Biological Importance    Trafford
# 14  Site of Biological Importance    Tameside
# 15  Site of Biological Importance    Tameside
# 16  Site of Biological Importance    Trafford
# 17  Site of Biological Importance    Rochdale
# 18  Site of Biological Importance    Rochdale
# 19  Site of Biological Importance      Bolton
# 20  Site of Biological Importance  Manchester
# 21  Site of Biological Importance    Trafford
# 22  Site of Biological Importance  Manchester
# 23  Site of Biological Importance    Tameside
# 24  Site of Biological Importance       Wigan
# 25  Site of Biological Importance  Manchester
# 26  Site of Biological Importance      Oldham
# 27  Site of Biological Importance    Trafford
# 28  Site of Biological Importance      Bolton
# 29  Site of Biological Importance        Bury
# 30  Site of Biological Importance  Manchester
# 31  Site of Biological Importance  Manchester
# 32  Site of Biological Importance      Bolton
# 33  Site of Biological Importance      Oldham
# 34  Site of Biological Importance    Tameside
# 35  Site of Biological Importance  Manchester
# 36  Site of Biological Importance      Bolton
# 37  Site of Biological Importance        Bury
# 38  Site of Biological Importance    Trafford
# 39  Site of Biological Importance  Manchester
# 40  Site of Biological Importance        Bury
# 41  Site of Biological Importance     Salford
# 42  Site of Biological Importance        Bury
# 43  Site of Biological Importance      Oldham
# 44  Site of Biological Importance  Manchester
# 45  Site of Biological Importance  Manchester
# 46  Site of Biological Importance       Wigan
#
#                                               SiteRef  \
# 0                              Ponds at Primrose Lane
# 1                           Meadow near Kirkless Hall
# 2                                           Firs Park
# 3                                  Bradford Reservoir
# 4                              Wetland near Radcliffe
# 5                                   Bridgewater Canal
# 6                                       Three Sisters
# 7                               Salford Quays (North)
# 8                                Blackleach Reservoir
# 9                                        Clayton Vale
# 10                                             Dacres
# 11                                  Bridgewater Canal
# 12                           Bentley & Tomfield Banks
# 13                              Salford Quays (South)
# 14                                   Puddle Clay Pits
# 15                                     Gower Hey Wood
# 16                          Wetland Near Balfour Road
# 17                                Scowcroft Reservoir
# 18                                  Queen's Park Lake
# 19              Smith Road Reservoirs & Raikes Clough
# 20                            Reservoirs at Harpurhey
# 21                                   Devisdale Meadow
# 22                                 Bank Bridge Meadow
# 23                                Ashton Canal (East)
# 24                                  Amberswood Common
# 25                                  Broadhurst Clough
# 26  Rochdale Canal - Lock at Scowcroft Farm to Sto...
# 27                                 King George V Pool
# 28                                       Crown Clough
# 29                                           Townside
# 30                                Ashton Canal (West)
# 31  Rochdale Canal - Stott's Lane to Ducie Street ...
# 32                                        Temple Road
# 33                                          Shaw Side
# 34                                 Stamford Park Lake
# 35                                Boggart Hole Clough
# 36                                         Moses Gate
# 37                                     Crow Lumb Wood
# 38                              Trafford Ecology Park
# 39                                     Boardman Brook
# 40             Manchester, Bolton & Bury Canal (East)
# 41                                       River Irwell
# 42                          Reservoirs at Chapelfield
# 43                            Ponds at Cowlishaw Farm
# 44                              Bowker Vale Reservoir
# 45                                     Moston Fairway
# 46                                      Three Sisters
#
#                                              geometry  \
# 0   POLYGON ((355587.865 410547.072, 355609.634 41...
# 1   POLYGON ((359875.249 406253.168, 359867.86 406...
# 2   POLYGON ((364518.048 400681.669, 364529.747 40...
# 3   POLYGON ((372273.276 407679.975, 372262.476 40...
# 4   POLYGON ((378742.219 407785.863, 378694.906 40...
# 5   POLYGON ((376376.965 399472.474, 376398.202 39...
# 6   POLYGON ((377597.954 399827.739, 377624.402 39...
# 7   POLYGON ((380483.893 397023.667, 380504.568 39...
# 8   POLYGON ((373653.338 403890.027, 373654.283 40...
# 9   MULTIPOLYGON (((388092.022 399403.207, 388099....
# 10  POLYGON ((398733.589 403899.581, 398741.645 40...
# 11  POLYGON ((376716.616 397607.814, 376722.38 397...
# 12  POLYGON ((378175.899 385203.318, 378175.737 38...
# 13  POLYGON ((380483.893 397023.667, 380541.04 396...
# 14  POLYGON ((397938.567 402624.027, 397948.432 40...
# 15  POLYGON ((394167.942 394172.026, 394170.256 39...
# 16  POLYGON ((377086.904 389511.299, 377128.778 38...
# 17  POLYGON ((388130.517 406603.417, 388131.993 40...
# 18  POLYGON ((385987.444 411731.879, 386018.146 41...
# 19  POLYGON ((373499.122 407460.589, 373515.806 40...
# 20  MULTIPOLYGON (((385432.136 401765.792, 385427....
# 21  POLYGON ((375499.146 387479.609, 375488.606 38...
# 22  POLYGON ((387302.261 399153.162, 387313.648 39...
# 23  POLYGON ((393510.395 398453.363, 393516.529 39...
# 24  MULTIPOLYGON (((361087.118 403657.732, 361063....
# 25  POLYGON ((387796.477 401351.484, 387804.821 40...
# 26  POLYGON ((389862.161 402504.014, 389861.378 40...
# 27  POLYGON ((377442.626 387951.459, 377452.602 38...
# 28  POLYGON ((363365.066 411787.346, 363343.25 411...
# 29  POLYGON ((380644.447 410264.652, 380637.595 41...
# 30  POLYGON ((389110.896 398002.202, 389110.624 39...
# 31  POLYGON ((388578.447 400697.631, 388553.225 40...
# 32  POLYGON ((370541.84 411382.612, 370568.446 411...
# 33  POLYGON ((394177.89 408243.847, 394171.478 408...
# 34  POLYGON ((395647.133 399560.211, 395634.683 39...
# 35  POLYGON ((386802.469 402885.453, 386836.978 40...
# 36  POLYGON ((374420.151 406612.698, 374420.151 40...
# 37  POLYGON ((379130.002 416389.149, 379129.854 41...
# 38  POLYGON ((379352.807 397387.947, 379350.302 39...
# 39  POLYGON ((386253.397 404708.603, 386253.317 40...
# 40  MULTIPOLYGON (((378159.227 407469.529, 378161....
# 41  POLYGON ((380855.74 400908, 380833.049 400952....
# 42  POLYGON ((378984.749 406094.496, 378984.601 40...
# 43  MULTIPOLYGON (((392837.76 408744.463, 392838.3...
# 44  MULTIPOLYGON (((383796.323 403133.857, 383811....
# 45  POLYGON ((388609.605 402302.351, 388608.871 40...
# 46  POLYGON ((357928.939 401185.293, 357957.618 40...
#
#                          centroid  No. Sites in 1km
# 0   POINT (355707.163 410520.464)                15
# 1   POINT (360000.375 406294.412)                15
# 2   POINT (364488.113 400600.946)                16
# 3    POINT (372190.425 407595.22)                19
# 4   POINT (378744.817 407815.339)                37
# 5    POINT (376333.494 398534.86)                21
# 6   POINT (377636.164 399700.487)                15
# 7   POINT (380794.224 396941.683)                33
# 8   POINT (373993.954 404068.892)                15
# 9   POINT (388277.776 399437.268)                24
# 10  POINT (398909.816 403978.854)                15
# 11  POINT (377393.735 391940.172)                21
# 12  POINT (378395.946 385314.884)                21
# 13  POINT (380756.383 396836.056)                38
# 14   POINT (398129.29 402832.215)                21
# 15  POINT (394213.052 394092.183)                16
# 16   POINT (377119.59 389446.484)                20
# 17  POINT (388186.567 406627.903)                23
# 18  POINT (386038.255 411640.494)                17
# 19  POINT (373304.022 407437.941)                15
# 20  POINT (385443.515 401656.633)                25
# 21  POINT (375508.306 387523.737)                16
# 22  POINT (387423.683 399200.371)                16
# 23  POINT (391415.533 397781.433)                15
# 24  POINT (360368.918 404017.052)                16
# 25  POINT (387839.439 401723.582)                24
# 26  POINT (389213.816 403660.323)                15
# 27  POINT (377586.755 387945.708)                29
# 28  POINT (363265.607 411676.727)                17
# 29  POINT (380530.067 410304.034)                37
# 30  POINT (387018.446 398443.835)                19
# 31  POINT (386480.007 399568.197)                20
# 32  POINT (370504.873 411321.736)                30
# 33  POINT (394024.986 408475.516)                20
# 34  POINT (395650.298 399507.093)                18
# 35  POINT (386588.923 402566.271)                19
# 36   POINT (374208.12 406614.742)                18
# 37  POINT (379094.671 416218.161)                17
# 38  POINT (379212.416 397407.091)                20
# 39  POINT (385900.085 404992.843)                18
# 40  POINT (377990.814 407585.338)                31
# 41  POINT (381802.932 400428.987)                18
# 42  POINT (378967.355 406195.683)                16
# 43  POINT (392918.186 408754.106)                17
# 44  POINT (383930.406 403005.688)                18
# 45  POINT (388383.182 401754.226)                24
# 46  POINT (358367.769 401012.636)                15

# %% [markdown]
# ## Find how these SBIs are threatened by different types of development

# %%
#Filter original data to just the "at risk" SBIs
# Out:
#                           Category      LAName  \
# 0    Site of Biological Importance       Wigan
# 1    Site of Biological Importance       Wigan
# 2    Site of Biological Importance       Wigan
# 3    Site of Biological Importance       Wigan
# 4    Site of Biological Importance       Wigan
# ..                             ...         ...
# 530  Site of Biological Importance    Trafford
# 531  Site of Biological Importance    Tameside
# 533  Site of Biological Importance  Manchester
# 534  Site of Biological Importance  Manchester
# 535  Site of Biological Importance      Bolton
#
#                                   SiteRef  \
# 0                                Big Wood
# 1                   Winstanley Hall Woods
# 2             Ackhurst Lane Sand Workings
# 3                             Abbey Lakes
# 4                           Wetland by M6
# ..                                    ...
# 530                 Sinderland Green Wood
# 531  Mill Race & Pasture at Haughton Dale
# 533                         Nan Nook Wood
# 534                              Big Wood
# 535                     Bank Wood & Marsh
#
#                                               geometry  \
# 0    POLYGON ((353649.752 410536.46, 353660.55 4105...
# 1    MULTIPOLYGON (((354300.461 403639.988, 354318....
# 2    POLYGON ((354320.268 407088.639, 354329.097 40...
# 3    POLYGON ((352622.159 404628.83, 352625.623 404...
# 4    MULTIPOLYGON (((354408.45 411806.416, 354430.9...
# ..                                                 ...
# 530  POLYGON ((373343.708 390508.261, 373343.663 39...
# 531  MULTIPOLYGON (((393687.128 393384.895, 393682....
# 533  POLYGON ((381158.403 390125.048, 381156.853 39...
# 534  MULTIPOLYGON (((383512.797 386267.952, 383512....
# 535  POLYGON ((369344.075 408685.587, 369329.313 40...
#
#                           centroid
# 0    POINT (353331.975 410159.462)
# 1    POINT (354500.103 403252.365)
# 2     POINT (354217.366 407048.76)
# 3     POINT (352671.79 404738.385)
# 4     POINT (354504.673 411797.58)
# ..                             ...
# 530  POINT (373296.047 390522.307)
# 531  POINT (393841.341 393512.227)
# 533  POINT (380888.856 390037.976)
# 534  POINT (383309.435 386406.658)
# 535  POINT (368971.201 408737.581)
#
# [489 rows x 5 columns]
